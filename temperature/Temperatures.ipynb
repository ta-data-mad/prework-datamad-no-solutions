# %%
# assign a variable to the list of temperatures
temperatures_C = [33,66,65,0,59,60,62,64,70,76,80,81,80,83,90,79,61,53,50,49,53,48,45,39]

# 1. Calculate the minimum of the list and print the value using print()

print("minium =", min(temperatures_C))

# 2. Calculate the maximum of the list and print the value using print()

print("maximum =", max(temperatures_C))

# 3. Items in the list that are greater than 70ºC and print the result
greater_70=[]

for e in temperatures_C:
    if e>70:
        greater_70.append(e)
        
print("temperatures higher or equal than 70ºC ", greater_70)


# 4. Calculate the mean temperature throughout the day and print the result

suma = sum(temperatures_C)

lena=len(temperatures_C)

media= suma / lena

print(media)




# 5.1 Solve the fault in the sensor by estimating a value
mean1=[]


def miss(temperatures_C):
    for e in temperatures_C:
        if e==0:
            temperatures_C.remove(e)
            mean1= sum(temperatures_C) / len(temperatures_C)
    return int(mean1)



print("Estimation of the temperature at 3:00 =", miss(temperatures_C))

# 5.2 Update of the estimated value at 03:00 on the list

temperatures_C[3]=62.0

print("Corrected temperatures after estimation:",  temperatures_C)


# Bonus: convert the list of ºC to ºFarenheit

# Formula: F = 1.8 * C + 32

formula=[]

for e in temperatures_C:
    formula=1.8 * e +32

    
print("Temperatures in Fahrenheit Grades =", formula)



# Print True or False depending on whether you would change the cooling system or not


repeat=[]

for e in temperatures_C:
    if e>70:
        repeat.count(e)
        repeat.append(e)
        
        
    elif e>80:
        print(true)
    elif media >65:
        print(true)

print(len(repeat)>4) 
    

# 1. We want the hours (not the temperatures) whose temperature exceeds 70ºC

hours1=[]

for e, i in enumerate(temperatures_C):
    if i > 70:
        hours1.append(e)

print(hours1)
        
    
# 2. Condition that those hours are more than 4 consecutive and consecutive,
#    not simply the sum of the whole set. Is this condition met?
hours2=[]

for e in hours1:
    if e < e+1:
        hours2.append(e)

def checkConsecutive(hours1): 
    return sorted(hours1) == list(range(min(hours1), max(hours1)+1)) 

print(checkConsecutive(hours1)) 

# 3. Average of each of the lists (ºC and ºF). How they relate?


suma2=sum(temperatures_C)
len2=len(temperatures_C)
media2=suma2/len2
    
print(float(media2))

# 4. Standard deviation of each of the lists. How they relate?
# Out:
# minium = 0
# maximum = 90
# temperatures higher or equal than 70ºC  [76, 80, 81, 80, 83, 90, 79]
# 60.25
# Estimation of the temperature at 3:00 = 62
# Corrected temperatures after estimation: [33, 66, 65, 62.0, 60, 62, 64, 70, 76, 80, 81, 80, 83, 90, 79, 61, 53, 50, 49, 53, 48, 45, 39]
# Temperatures in Fahrenheit Grades = 102.2
# True
# [8, 9, 10, 11, 12, 13, 14]
# True
# 63.0
