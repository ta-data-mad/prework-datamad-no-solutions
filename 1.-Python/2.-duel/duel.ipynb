# %% [markdown]
# # Duel of sorcerers
# ## Intro
# You are witnessing an epic battle between two powerful sorcerers: Gandalf and Saruman. Each sorcerer has 10 spells of variable power in their mind and they are going to throw them one after the other. The winner of the duel will be the one who wins more of those clashes between spells. Spells are represented as a list of 10 integers whose value equals the power of the spell.
# ```
# gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
# saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]
# ```
# For example:
# 1. The first clash is won by Saruman: 10 against 23, wins 23
# 2. The second clash wins Saruman: 11 against 66, wins 66
# 3. etc.
#
#
# You will create two variables, one for each sorcerer, where the sum of clashes won will be stored. Depending on which variable is greater at the end of the duel, you will show one of the following three results on the screen:
# * Gandalf wins
# * Saruman wins
# * Tie
#
# <img src="images/content_lightning_bolt_big.jpg" width="400">
#
# ## LINKS:
# * zip: https://www.programiz.com/python-programming/methods/built-in/zip

# %% [markdown]
# ## Solution

# %%
# Assign spell power lists to variables
gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]

# %%
# Assign 0 to each variable that stores the victories
gandalf_wins = 0
saruman_wins = 0

# %%
# Execution of spell clashes
spells = len(gandalf)
for i in range(0,spells):
    
    gandalf_spell=gandalf[i]
    saruman_spell=saruman[i]
    
    if gandalf_spell>saruman_spell:
        gandalf_wins+=1
        
    elif gandalf_spell<saruman_spell:
        saruman_wins+=1

    
print("Gandalf wins", gandalf_wins, "times and Saruman wins", saruman_wins, "times")
# Out:
# Gandalf wins 6 times and Saruman wins 4 times

# %% [markdown]
# **Expected output**:
# ```
# 6
# 4
# ```

# %%
# We check who has won, do not forget the possibility of a draw.
# Print the result based on the winner.
if gandalf_wins>saruman_wins:
    print("Gandalf wins")
elif gandalf_wins<saruman_wins:
    print("Saruman wins")
else:
    print("It's a tie")
# Out:
# Gandalf wins

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %% [markdown]
# ## Goals
#
# 1. Treatment of lists
# 2. Use of **for loop**
# 3. Use of conditional **if-elif-else**
# 4. Use of the functions **range(), len()**
# 5. print()
# 6. zip()

# %% [markdown]
# ## Bonus
#
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.
# 3. Average of each of the spell lists.
# 4. Standard deviation of each of the spell lists.
#
# ```
# POWER = {
#     'Fireball': 50,
#     'Lightning bolt': 40,
#     'Magic arrow': 10,
#     'Black Tentacles': 25,
#     'Contagion': 45
# }
#
# gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball',
#            'Magic arrow', 'Lightning bolt', 'Fireball', 'Fireball', 'Fireball']
# saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles',
#            'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']
# ```
#
# Good luck!

# %%
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# variables

POWER = {
    'Fireball': 50, 
    'Lightning bolt': 40, 
    'Magic arrow': 10, 
    'Black Tentacles': 25, 
    'Contagion': 45
}

gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball', 
           'Magic arrow', 'Lightning bolt', 'Fireball', 'Magic arrow', 'Fireball']
saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles', 
           'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']

spells = len(gandalf)

gandalf_wins = 0
saruman_wins = 0

# %%
# Assign spell power lists to variables
gandalf_power=[]
saruman_power=[]

for i in range(0,spells):
    gandalf_power.append(POWER[gandalf[i]])
    saruman_power.append(POWER[saruman[i]])
((gandalf_power),(saruman_power))
# Out:
# ([50, 40, 40, 10, 50, 10, 40, 50, 10, 50],
#  [45, 45, 25, 50, 25, 40, 10, 45, 10, 10])

# %% [markdown]
# **Expected output**:
# ```
# ([50, 40, 40, 10, 50, 10, 40, 50, 10, 50],
#  [45, 45, 25, 50, 25, 40, 10, 45, 10, 10])
#  ```

# %%
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.
# Execution of spell clashes
# check clashes
# check for 3 wins in a row
# check the winner
# count sum of clashes

gandalf_wins = 0
saruman_wins = 0

for i in range(0,spells):
    
    gandalf_spell=gandalf_power[i]
    saruman_spell=saruman_power[i]
    
    if gandalf_spell>saruman_spell:
        gandalf_wins+=1
        saruman_wins=0
    elif gandalf_spell<saruman_spell:
        saruman_wins+=1
        gandalf_wins=0

    if saruman_wins>=3:
        print("Saruman wins")
        break
    elif gandalf_wins>=3:
        print("Gandalf wins")
        break
if gandalf_wins <3 & saruman_wins <3:
    print("None of them has won")
# Out:
# Gandalf wins

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %%
# 3. Average of each of the spell lists.
gandalf_mean=sum(gandalf_power)/spells
saruman_mean=sum(saruman_power)/spells


print("The average spell power of Gandalf is",gandalf_mean,"\n")
print("The average spell power of Saruman is",saruman_mean)
# Out:
# The average spell power of Gandalf is 35.0
#
# The average spell power of Saruman is 30.5

# %% [markdown]
# **Expected output**:
# ```
# 35.0
# 30.5
# ```

# %%
# 4. Standard deviation of each of the spell lists.
gandalf_power
gandalf_mean
spells

calc_gandalf = []

for i in gandalf_power:
    calc_gandalf.append((i-gandalf_mean)**2)
    
sd_gandalf=((sum(calc_gandalf))/spells)**(1/2)

print("The standard deviation of Gandalf's spell power is", sd_gandalf,"\n")

saruman_power
saruman_mean
spells

calc_saruman = []

for i in saruman_power:
    calc_saruman.append((i-saruman_mean)**2)
    
sd_saruman=(sum(calc_saruman)/spells)**(1/2)

print("The standard deviation of Saruman's spell power is", sd_saruman)
# Out:
# The standard deviation of Gandalf's spell power is 16.881943016134134
#
# The standard deviation of Saruman's spell power is 15.56438241627338

# %% [markdown]
# **Expected output**:
# ```
# 16.881943016134134
# 15.56438241627338
# ```

# %%
import statistics

print("The average spell power of Gandalf is", statistics.mean(gandalf_power),"\n")
print("The average spell power of Saruman is",statistics.mean(saruman_power),"\n")

print("The standard deviation of Gandalf's spell power is", statistics.pstdev(gandalf_power),"\n")
print("The standard deviation of Saruman's spell power is", statistics.pstdev(saruman_power),"\n")
# Out:
# The average spell power of Gandalf is 35
#
# The average spell power of Saruman is 30.5
#
# The standard deviation of Gandalf's spell power is 16.881943016134134
#
# The standard deviation of Saruman's spell power is 15.56438241627338
