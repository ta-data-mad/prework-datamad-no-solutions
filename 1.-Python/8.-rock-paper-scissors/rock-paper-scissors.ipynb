# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
gestures=["stone","paper","scissors"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
n_rounds=3

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
rounds_to_win=round(n_rounds/2+1)

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def cpu_choice():
    cpu=random.choice(gestures)
    return cpu
# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def player_choice():
    print("Which is the gesture that you want to show 'stone', 'paper' or 'scissors'?")
    player=str(input())
    while player not in gestures:
        print("Please check your spelling.\n")
        print("Which is the gesture that you want to show 'stone', 'paper' or 'scissors'?")
        player=str(input())
    return player

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def combat(x,y):
    if x == "scissors" and y == "stone":
        return 2
    elif x == "stone" and y == "paper":
        return 2
    elif x == "stone" and y == "scissors":
        return 1
    elif x == "paper" and y == "stone":
        return 1
    elif x == "paper" and y == "scissors":
        return 2
    elif x == "scissors" and y == "paper":
        return 1
    else:
        return 0
    
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def printing (x,y):
    print("The computer choice is: ",x )
    print("Your choice is: ", y)
    result=combat(x,y)
    if result == 0:
        print("It's a tie!")
    elif result == 2:
        print("You win this round!")
    elif result == 1:
        print("The computer wins this round!")   


    
# Create two variables that accumulate the wins of each participant
cpu_score=0
player_score=0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while player_score<=rounds_to_win and cpu_score<=rounds_to_win:
    cpu=cpu_choice()
    player=player_choice()
    result=combat(cpu,player)
    printing (cpu,player)
    if result == 2:
        player_score +=1
    elif result == 1:
        cpu_score +=1

# Print by console the winner of the game based on who has more accumulated wins
if player_score > cpu_score:
    print("Congratulation! You won the game!")
elif player_score < cpu_score:
    print("Ooohh! The computer won the game.")
else:
    print("It's a tie!")
# Out:
# Which is the gesture that you want to show 'stone', 'paper' or 'scissors'?
# paper
# The computer choice is:  scissors
# Your choice is:  paper
# The computer wins this round!
# Which is the gesture that you want to show 'stone', 'paper' or 'scissors'?
# paper
# The computer choice is:  scissors
# Your choice is:  paper
# The computer wins this round!
# Which is the gesture that you want to show 'stone', 'paper' or 'scissors'?
# paper
# The computer choice is:  scissors
# Your choice is:  paper
# The computer wins this round!
# Ooohh! The computer won the game.

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def odd_number():
    try:
        print("Please, enter an odd number")
        odd=int(input())
        while odd%2 == 0:
            print("Please enter an odd number")
            odd=int(input())
    except:
        print("Only numerical chars")
    
    return odd

# Assign a list of 5 possible options.

gestures=["stone","paper","scissors","lizard","spock"]
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
n_rounds=odd_number()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
rounds_to_win=round(n_rounds/2+1)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def cpu_choice():
    cpu=random.choice(gestures)
    return cpu

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def player_choice():
    print("Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?")
    player=str(input())
    while player not in gestures:
        print("Please check your spelling.\n")
        print("Which is the gesture that you want to show 'stone', 'paper' or 'scissors'?")
        player=str(input())
    return player

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def combat(x,y):
    if x == "scissors" and y == "stone":
        return 2
    elif x == "scissors" and y == "paper":
        return 1
    elif x == "scissors" and y == "lizard":
        return 1
    elif x == "scissors" and y == "spock":
        return 2 
    elif x == "stone" and y == "paper":
        return 2
    elif x == "stone" and y == "scissors":
        return 1
    elif x == "stone" and y == "lizard":
        return 1
    elif x == "stone" and y == "spock":
        return 2  
    elif x == "paper" and y == "stone":
        return 1
    elif x == "paper" and y == "scissors":
        return 2
    elif x == "paper" and y == "lizard":
        return 2
    elif x == "paper" and y == "spock":
        return 1
    elif x == "lizard" and y == "stone":
        return 2
    elif x == "lizard" and y == "scissors":
        return 2
    elif x == "lizard" and y == "paper":
        return 1
    elif x == "lizard" and y == "spock":
        return 1 
    elif x == "spock" and y == "stone":
        return 1
    elif x == "spock" and y == "scissors":
        return 1
    elif x == "spock" and y == "paper":
        return 2
    elif x == "spock" and y == "lizard":
        return 2 
    else:
        return 0

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def printing (x,y):
    print("The computer choice is: ",x )
    print("Your choice is: ",y)
    result=combat(x,y)
    if result == 0:
        print("It's a tie!")
    elif result == 2:
        print("You win this round!")
    elif result == 1:
        print("The computer wins this round!")
    
# Create two variables that accumulate the wins of each participant
cpu_score=0
player_score=0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.


while player_score<=rounds_to_win and cpu_score<=rounds_to_win:
    cpu=cpu_choice()
    player=player_choice()
    result=combat(cpu,player)
    printing (cpu,player)
    if result == 2:
        player_score +=1
    elif result == 1:
        cpu_score +=1
print(n_rounds)    
# Print by console the winner of the game based on who has more accumulated wins
if player_score > cpu_score:
    print("Congratulation! You won the game!")
elif player_score < cpu_score:
    print("Ooohh! The computer won the game.")
else:
    print("It's a tie!")
# Out:
# Please, enter an odd number
# 3
# Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# paper
# The computer choice is:  scissors
# Your choice is:  paper
# The computer wins this round!
# Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# paper
# The computer choice is:  paper
# Your choice is:  paper
# It's a tie!
# Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# paper
# The computer choice is:  paper
# Your choice is:  paper
# It's a tie!
# Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# paper
# The computer choice is:  spock
# Your choice is:  paper
# You win this round!
# Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# paper
# The computer choice is:  paper
# Your choice is:  paper
# It's a tie!
# Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# paper
# The computer choice is:  lizard
# Your choice is:  paper
# The computer wins this round!
# Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# paper
# The computer choice is:  spock
# Your choice is:  paper
# You win this round!
# Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# paper
# The computer choice is:  paper
# Your choice is:  paper
# It's a tie!
# Which is the gesture that you want to show 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# paper
# The computer choice is:  spock
# Your choice is:  paper
# You win this round!
# 3
# Congratulation! You won the game!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
