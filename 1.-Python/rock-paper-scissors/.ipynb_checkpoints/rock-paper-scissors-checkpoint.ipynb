# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

gestures=['rock', 'paper', 'scissors']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

games = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

min_games_win = int(games/2)+1

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def pc_choise():
    global cpu_choise
    cpu_choise = random.choice(gestures)
    return cpu_choise

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def your_choise():
    global player_choise
    player_choise = ''
    while player_choise.lower() not in gestures:
        player_choise = input('What\'s your choise: rock, paper or scissors?')    
    return player_choise.lower()


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def combat(player_choise, cpu_choise):
    global result
    
    if player_choise != cpu_choise:
        if player_choise == 'rock':
            if cpu_choise == 'paper':
                result = 1
            else:
                result = 2
        elif player_choise == 'paper':
            if cpu_choise == 'scissors':
                result = 1
            else:
                result = 2
        elif player_choise == 'scissors':
            if cpu_choise == 'rock':
                result = 1
            else:
                result = 2
    else:
        result = 0
    return result
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
# Create two variables that accumulate the wins of each participant

cpu_score=0
player_score=0

def who_won(result):
    global player_score
    global cpu_score
    if result == 1:
        print('you choose is:', player_choise, 'pc choose is:', cpu_choise, ', so you LOSE')
        cpu_score += 1
    elif result == 2:
        print('you choose is:', player_choise, 'pc choose is:', cpu_choise, ', so you WIN')
        player_score += 1
    else:
        print('you choose is:', player_choise, 'pc choose is:', cpu_choise, ', so TIE')
    



# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

for x in range(games):
    if player_score < min_games_win and cpu_score < min_games_win:
        pc_choise()
        your_choise()
        combat(player_choise, cpu_choise)
        who_won(result)
    else:
        break     
# Print by console the winner of the game based on who has more accumulated wins

if cpu_score == min_games_win:
    print('....................CPU WIN........................')
elif player_score == min_games_win:
    print('....................YOU WIN........................')
else:
    print('......................TIE..........................')
# Out:
# What's your choise: rock, paper or scissors?rock
# you choose is: rock pc choose is: rock , so TIE
# What's your choise: rock, paper or scissors?PAPER
# you choose is: PAPER pc choose is: paper , so TIE
# What's your choise: rock, paper or scissors?PAPER
# you choose is: PAPER pc choose is: scissors , so TIE
# What's your choise: rock, paper or scissors?scissors
# you choose is: scissors pc choose is: rock , so you LOSE
# What's your choise: rock, paper or scissors?rock
# you choose is: rock pc choose is: scissors , so you WIN
# ......................TIE..........................

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module

import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking

def odd_number():
    odd_number = 0
    while (odd_number)%2==0: 
        odd_number = int(input('choose an odd number..'))
    return odd_number
odd_number()
# Assign a list of 5 possible options.

gestures = ['rock', 'paper', 'scissors', 'lizard', 'spock']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used

games = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

min_win = int(games/2)+1 

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.

def pc_choise():
    global cpu_choise
    cpu_choise = random.choice(gestures)
    return cpu_choise


# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

def your_choise():
    global player_choise
    player_choise = ''
    while player_choise.lower() not in gestures:
        player_choise = input('What\'s your choise: rock, paper, scissors, lizard or spock?')    
    return player_choise.lower()

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options

def combat(player_choise, cpu_choise):
    global result
    
    if player_choise != cpu_choise:
        if player_choise == 'rock':
            if cpu_choise == 'paper' or cpu_choise == 'spock' :
                result = 1
            else:
                result = 2
        elif player_choise == 'paper':
            if cpu_choise == 'scissors' or cpu_choise == 'lizard':
                result = 1
            else:
                result = 2
        elif player_choise == 'scissors':
            if cpu_choise == 'rock' or cpu_choise == 'spock':
                result = 1
            else:
                result = 2
        elif player_choise == 'lizard':
            if cpu_choise == 'rock' or cpu_choise == 'scissors':
                result = 1
            else:
                result = 2
        elif player_choise == 'spock':
            if cpu_choise == 'paper' or cpu_choise == 'lizard':
                result = 1
            else:
                result = 2                
    else:
        result = 0
    return result
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
# Create two variables that accumulate the wins of each participant
cpu_score=0
player_score=0

def who_won(result):
    global player_score
    global cpu_score
    if result == 1:
        print('you choose is:', player_choise, 'pc choose is:', cpu_choise, ', so you LOSE')
        cpu_score += 1
    elif result == 2:
        print('you choose is:', player_choise, 'pc choose is:', cpu_choise, ', so you WIN')
        player_score += 1
    else:
        print('you choose is:', player_choise, 'pc choose is:', cpu_choise, ', so TIE')
    



# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

for x in range(games):
    if player_score < min_win and cpu_score < min_win:
        pc_choise()
        your_choise()
        combat(player_choise, cpu_choise)
        who_won(result)
    else:
        break 
    
# Print by console the winner of the game based on who has more accumulated wins

if cpu_score == min_win:
    print('....................CPU WIN........................')
elif player_score == min_win:
    print('....................YOU WIN........................')
else:
    print('......................TIE..........................')
# Out:
# choose an odd number..4
# choose an odd number..5
# What's your choise: rock, paper, scissors, lizard or spock?rock
# you choose is: rock pc choose is: lizard , so you WIN
# What's your choise: rock, paper, scissors, lizard or spock?paper
# you choose is: paper pc choose is: scissors , so you LOSE
# What's your choise: rock, paper, scissors, lizard or spock?scissors
# you choose is: scissors pc choose is: lizard , so you WIN
# What's your choise: rock, paper, scissors, lizard or spock?s
# What's your choise: rock, paper, scissors, lizard or spock?lizard
# you choose is: lizard pc choose is: spock , so you WIN
# ....................YOU WIN........................

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
