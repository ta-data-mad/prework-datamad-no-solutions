# %% [markdown]
# # Snail and well
#
# A snail falls at the bottom of a 125 cm well. Each day the snail rises 30 cm. But at night, while sleeping, slides 20 cm because the walls are wet. How many days does it take to escape from the well?
#
# TIP: http://puzzles.nigelcoldwell.co.uk/sixtytwo.htm

# %% [markdown]
# ## Solución

# %%
# Assign problem data to variables with representative names
# well height, daily advance, night retreat, accumulated distance
well_height = 125
daily_advance = 30
night_retreat = -20
accumulated_distance = 0

# Assign 0 to the variable that represents the solution
days = 0

# Write the code that solves the problem

while accumulated_distance < well_height: 
    days+=1
    accumulated_distance+=daily_advance
    if accumulated_distance >= well_height:
        break
    accumulated_distance+=night_retreat

# Print the result with print('Days =', days)
print("The snail escaped in", days, "days")
# Out:
# The snail escaped in 11 days

# %% [markdown]
# **Expected output**:
# ```
# Days = 11
# ```

# %% [markdown]
# ## Goals
#
# 1. Treatment of variables
# 2. Use of loop **while**
# 3. Use of conditional **if-else**
# 4. Print in console

# %% [markdown]
# ## Bonus
# The distance traveled by the snail is now defined by a list.
# ```
# advance_cm = [30, 21, 33, 77, 44, 45, 23, 45, 12, 34, 55]
# ```
# How long does it take to raise the well?
#
# What is its maximum displacement in one day? And its minimum?
#
# What is its average speed during the day?
#
# What is the standard deviation of its displacement during the day?

# %%
# Assign problem data to variables with representative names
# well height, daily advance, night retreat, accumulated distance
advance_cm = [30, 21, 33, 77, 44, 45, 23, 45, 12, 34, 55]

well_height = 125
night_retreat = -20
accumulated_distance = 0

# Assign 0 to the variable that represents the solution
days=0

# Write the code that solves the problem
for i in advance_cm:
    
    if accumulated_distance < well_height:
        accumulated_distance += i
        accumulated_distance += night_retreat
        days += 1
    else:
        break
           
# Print the result with print('Days =', days)
print("Days = ", days)
# Out:
# Days =  6

# %% [markdown]
# **Expected output**:
# ```
# Days = 6
# ```

# %%
# What is its maximum displacement in a day? And its minimum?
print ("The maximum displacement in one day is", max(advance_cm) ,"\n")
print ("The minimum displacement in one day is", min(advance_cm))
# Out:
# The maximum displacement in one day is 77
#
# The minimum displacement in one day is 12

# %% [markdown]
# **Expected output**:
# ```
# 77 12
# ```

# %%
# What is its average progress?  
print ("The average progress is", sum(advance_cm)/len(advance_cm))
# Out:
# The average progress is 38.09090909090909

# %% [markdown]
# **Expected output**:
# ```
# 38.09090909090909
# ```

# %%
# What is the standard deviation of your displacement during the day?
mean_daily_distance= sum(advance_cm)/len(advance_cm)

new_list = []

for i in advance_cm:
    new_list.append((i-mean_daily_distance)**2)
    SD=(sum(new_list)/len(new_list))**(1/2)

print("The standard deviation of its displacement is", SD)
# Out:
# The standard deviation of its displacement is 17.159437082600803

# %% [markdown]
# **Expected output**:
# ```
# 17.159437082600803
# ```

# %%
import statistics
print ("The average progress is", statistics.mean(advance_cm),"\n")
print("The standard deviation of its displacement is", statistics.pstdev(advance_cm))
# Out:
# The average progress is 38.09090909090909
#
# The standard deviation of its displacement is 17.159437082600803
