# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list



# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...



# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games



# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.



# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins


# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

    
# Create two variables that accumulate the wins of each participant


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.


# Print by console the winner of the game based on who has more accumulated wins

# %%
import random

game_options=["rock", "paper", "scissors"]
max_games=5
to_win=3
choice=""
game_options=["rock", "paper", "scissors"]
machine=0
human=0
count=0
machine_wins=0
human_wins=0
while count<max_games:
    if human==to_win:
        print("The best of three is human")
        break
    if machine==to_win:
        print("The best of three is machine")
        break
    choice=input("Please choose between: rock, paper or scissors ")
    if choice in game_options:
        random_option=random.choice(game_options)
    if choice==random_option:
        print("0")
        machine+=0
        human+=0
        count+=1
    elif choice=="rock":
        if random_option=="paper":
            print("1")
            machine+=1
            human+=0
            count+=1
            machine_wins+=1
        else:
            print("2")
            machine+=0
            human+=1
            count+=1
            human_wins+=1
    elif choice=="paper":
        if random_option=="scissors":
            print("1")
            machine+=1
            human+=0
            count+=1
            machine_wins+=1
        else:
            print("2")
            machine+=0
            human+=1
            count+=1
            human_wins+=1
    elif choice=="scissors":
        if random_option=="rock":
            print("2")
            machine+=1
            human+=0
            count+=1
            machine_wins+=1
        else:
            print("1")
            machine+=0
            human+=1
            count+=1
            human_wins+=1
    print("Machine: ", random_option, "Human: ", output[choice])
    print("Machine points:", machine, "Human points:", human)
    if choice not in game_options:
        print("Sorry, you must choose between: rock, paper or scissors")
print("Machine wins:", machine_wins, "Human wins:", human_wins)
if machine_wins==human_wins:
    print("Tie!")
elif machine_wins>human_wins:
        print("Machine wins")
elif machine_wins<human_wins:
        print("Human wins")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-187-c382da6fe710> in <module>
#      18         print("The best of three is machine")
#      19         break
# ---> 20     choice=input("Please choose between: rock, paper or scissors ")
#      21     if choice in game_options:
#      22         random_option=random.choice(game_options)
#
# /usr/local/Cellar/jupyterlab/2.2.5/libexec/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/Cellar/jupyterlab/2.2.5/libexec/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module


# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking


# Assign a list of 5 possible options.


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games


# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.


# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options


    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

    
# Create two variables that accumulate the wins of each participant


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
    
    
# Print by console the winner of the game based on who has more accumulated wins

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %%
import random

game_options=["rock", "paper", "scissors", "lizard", "spock"]
games=["5", "7", "9", "11", "13"]
to_win=["3", "5", "7", "9", "11"]
choice=""
rounds_number=""
game_options=["rock", "paper", "scissors", "lizard", "spock"]
machine=0
human=0
count=0
machine_wins=0
human_wins=0
rounds_number=input("Please choose an odd number between 5 and 13 ")
if rounds_number in games:
    rounds=int(rounds_number)
    print(rounds_number, "rounds")
    while count<rounds:
        choice=input("Please choose between: rock, paper, scissors, lizard or spock ")
        if choice in game_options:
            random_option=random.choice(game_options)
        if choice==random_option:
            print("0")
            machine+=0
            human+=0
            count+=1
        elif choice=="rock":
            if random_option=="paper":
                print("1")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1
            elif random_option=="spock":
                print("1")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1 
            else:
                print("2")
                machine+=0
                human+=1
                count+=1
                human_wins+=1
        elif choice=="paper":
            if random_option=="scissors":
                print("1")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1
            elif random_option=="lizard":
                print("1")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1
            else:
                print("2")
                machine+=0
                human+=1
                count+=1
                human_wins+=1
        elif choice=="scissors":
            if random_option=="rock":
                print("2")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1
            elif random_option=="spock":
                print("2")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1
            else:
                print("1")
                machine+=0
                human+=1
                count+=1
                human_wins+=1
        elif choice=="spock":
            if random_option=="lizard":
                print("2")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1
            elif random_option=="paper":
                print("2")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1
            else:
                print("1")
                machine+=0
                human+=1
                count+=1
                human_wins+=1
        elif choice=="lizard":
            if random_option=="rock":
                print("2")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1
            elif random_option=="scissors":
                print("2")
                machine+=1
                human+=0
                count+=1
                machine_wins+=1
        print("Machine: ", random_option, "Human: ", output[choice])
        print("Machine points:", machine, "Human points:", human)
        if choice not in game_options:
            print("Sorry, you must choose between: rock, paper or scissors")
    print("Machine wins:", machine_wins, "Human wins:", human_wins)
    if machine_wins==human_wins:
        print("Tie!")
    elif machine_wins>human_wins:
        print("Machine wins")
    elif machine_wins<human_wins:
        print("Human wins")
if rounds_number not in games:
    print("Sorry, you must choose an odd number between 5 and 13")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-186-b0c8c707b351> in <module>
#      12 machine_wins=0
#      13 human_wins=0
# ---> 14 rounds_number=input("Please choose an odd number between 5 and 13 ")
#      15 if rounds_number in games:
#      16     rounds=int(rounds_number)
#
# /usr/local/Cellar/jupyterlab/2.2.5/libexec/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/Cellar/jupyterlab/2.2.5/libexec/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
