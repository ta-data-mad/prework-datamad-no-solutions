# %% [markdown]
# # Duel of sorcerers
# ## Intro
# You are witnessing an epic battle between two powerful sorcerers: Gandalf and Saruman. Each sorcerer has 10 spells of variable power in their mind and they are going to throw them one after the other. The winner of the duel will be the one who wins more of those clashes between spells. Spells are represented as a list of 10 integers whose value equals the power of the spell.
# ```
# gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
# saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]
# ```
# For example:
# 1. The first clash is won by Saruman: 10 against 23, wins 23
# 2. The second clash wins Saruman: 11 against 66, wins 66
# 3. etc.
#
#
# You will create two variables, one for each sorcerer, where the sum of clashes won will be stored. Depending on which variable is greater at the end of the duel, you will show one of the following three results on the screen:
# * Gandalf wins
# * Saruman wins
# * Tie
#
# <img src="images/content_lightning_bolt_big.jpg" width="400">
#
# ## LINKS:
# * zip: https://www.programiz.com/python-programming/methods/built-in/zip

# %% [markdown]
# ## Solution

# %%
# Assign spell power lists to variables
gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]

spells = 0

# %%
# Assign 0 to each variable that stores the victories
gandalf_wins = 0
saruman_wins = 0
tie = 0

# %%
# Execution of spell clashes
j = 0
for i in gandalf:
    if(i > saruman[j]):
        gandalf_wins += 1
        j += 1
        spells += 2
    elif(i < saruman[j]):
        saruman_wins += 1
        j += 1
        spells += 2
    else:
        tie += 1
        spells += 2

print(gandalf_wins)
print(saruman_wins)
print(tie)
print(spells)
# Out:
# 6
# 4
# 0
# 20

# %% [markdown]
# **Expected output**:
# ```
# 6
# 4
# ```

# %%
# We check who has won, do not forget the possibility of a draw.
# Print the result based on the winner.
if (gandalf_wins > saruman_wins):
    print("Gandalf Wins!!")
elif(gandalf_wins < saruman_wins):
    print("Saruman Wins!!")
else:
    print("Tie!!")
# Out:
# Gandalf Wins!!

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %% [markdown]
# ## Goals
#
# 1. Treatment of lists
# 2. Use of **for loop**
# 3. Use of conditional **if-elif-else**
# 4. Use of the functions **range(), len()**
# 5. print()
# 6. zip()

# %% [markdown]
# ## Bonus
#
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.
# 3. Average of each of the spell lists.
# 4. Standard deviation of each of the spell lists.
#
# ```
# POWER = {
#     'Fireball': 50,
#     'Lightning bolt': 40,
#     'Magic arrow': 10,
#     'Black Tentacles': 25,
#     'Contagion': 45
# }
#
# gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball',
#            'Magic arrow', 'Lightning bolt', 'Fireball', 'Fireball', 'Fireball']
# saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles',
#            'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']
# ```
#
# Good luck!

# %%
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# variables

POWER = {
    'Fireball': 50, 
    'Lightning bolt': 40, 
    'Magic arrow': 10, 
    'Black Tentacles': 25, 
    'Contagion': 45
}

gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball', 
           'Magic arrow', 'Lightning bolt', 'Fireball', 'Magic arrow', 'Fireball']
saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles', 
           'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']

# %%
# Assign spell power lists to variables
list_powers_gandalf = []
list_powers_saruman = []
for spell in gandalf:
    powers_gandalf = POWER.get(spell)
    list_powers_gandalf.append(powers_gandalf)
for spell in saruman:
    powers_saruman = POWER.get(spell)
    list_powers_saruman.append(powers_saruman)
print(list_powers_gandalf)
print(list_powers_saruman)
# Out:
# [50, 40, 40, 10, 50, 10, 40, 50, 10, 50]
# [45, 45, 25, 50, 25, 40, 10, 45, 10, 10]

# %% [markdown]
# **Expected output**:
# ```
# ([50, 40, 40, 10, 50, 10, 40, 50, 10, 50],
#  [45, 45, 25, 50, 25, 40, 10, 45, 10, 10])
#  ```

# %%
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.
j = 0
gandalf_wins = 0
saruman_wins = 0
tie = 0
spells = 0
for i in list_powers_gandalf:
    if(i > list_powers_saruman[j]):
        gandalf_wins += 1
        saruman_wins = 0
        j += 1
        spells += 2
    elif(i < list_powers_saruman[j]):
        saruman_wins += 1
        gandalf_wins = 0
        j += 1
        spells += 2
    else:
        tie += 1
        spells += 2

if(gandalf_wins >= 3):
    print('Gandalf Wins!')
elif(saruman_wins >= 3):
    print('Saruman Wins!')
elif(gandalf_wins == saruman_wins):
    print('Tie!')
# Execution of spell clashes

# check clashes

# check for 3 wins in a row

# check the winner

# count sum of clashes
# Out:
# Gandalf Wins!

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %%
# 3. Average of each of the spell lists.
total_gandalf = 0
total_saruman = 0
for spells in list_powers_gandalf:
    total_gandalf = total_gandalf + spells
    average_gandalf = total_gandalf / len(list_powers_gandalf)
print(average_gandalf)
for spells in list_powers_saruman:
    total_saruman = total_saruman + spells
    average_saruman = total_saruman / len(list_powers_saruman)
print(average_saruman)
# Out:
# 35.0
# 30.5

# %% [markdown]
# **Expected output**:
# ```
# 35.0
# 30.5
# ```

# %%
# 4. Standard deviation of each of the spell lists.
sum_squares = 0

for spells in list_powers_gandalf:
    subst_average = spells - average_gandalf
    square = subst_average ** 2
    sum_squares = sum_squares + square

variance_gandalf = sum_squares / len(list_powers_gandalf)
standard_desviation_gandalf = variance_gandalf ** 0.5
print(standard_desviation_gandalf)

sum_squares = 0

for spells in list_powers_saruman:
    subst_average = spells - average_saruman
    square = subst_average ** 2
    sum_squares = sum_squares + square

variance_saruman = sum_squares / len(list_powers_saruman)
standard_desviation_saruman = variance_saruman ** 0.5
print(standard_desviation_saruman)
# Out:
# 16.881943016134134
# 15.56438241627338

# %% [markdown]
# **Expected output**:
# ```
# 16.881943016134134
# 15.56438241627338
# ```
