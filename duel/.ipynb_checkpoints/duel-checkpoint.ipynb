# %% [markdown]
# # Duel of sorcerers
# ## Intro
# You are witnessing an epic battle between two powerful sorcerers: Gandalf and Saruman. Each sorcerer has 10 spells of variable power in their mind and they are going to throw them one after the other. The winner of the duel will be the one who wins more of those clashes between spells. Spells are represented as a list of 10 integers whose value equals the power of the spell.
# ```
# gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
# saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]
# ```
# For example:
# 1. The first clash is won by Saruman: 10 against 23, wins 23
# 2. The second clash wins Saruman: 11 against 66, wins 66
# 3. etc.
#
#
# You will create two variables, one for each sorcerer, where the sum of clashes won will be stored. Depending on which variable is greater at the end of the duel, you will show one of the following three results on the screen:
# * Gandalf wins
# * Saruman wins
# * Tie
#
# <img src="images/content_lightning_bolt_big.jpg" width="400">
#
# ## LINKS:
# * zip: https://www.programiz.com/python-programming/methods/built-in/zip

# %% [markdown]
# ## Solution

# %%
# Assign spell power lists to variables
gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]

# %%
# Assign 0 to each variable that stores the victories
vitorias=0

# %%
# Execution of spell clashes

gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]
victorias=[]
victorias=0

[(i, j) for i in range(len(gandalf)) for j in range(len(saruman)) if gandalf[i] == saruman[j]]
list(zip(gandalf, saruman))

for gandalf, saruman in zip(gandalf, saruman):
    if gandalf>saruman:
        print(1, end= " ")
        
    elif gandalf<saruman:
        print(0, end= " ")
    else:
        print("draw")
# Out:
# 0 0 1 0 1 1 0 1 1 1

# %% [markdown]
# **Expected output**:
# ```
# 6
# 4
# ```

# %%
# We check who has won, do not forget the possibility of a draw.
# Print the result based on the winner.

if gandalf>saruman:
    print("Gandalf wins")
else:
    print("Saruman wins")
# Out:
# Gandalf wins

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %% [markdown]
# ## Goals
#
# 1. Treatment of lists
# 2. Use of **for loop**
# 3. Use of conditional **if-elif-else**
# 4. Use of the functions **range(), len()**
# 5. print()
# 6. zip()

# %% [markdown]
# ## Bonus
#
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.
# 3. Average of each of the spell lists.
# 4. Standard deviation of each of the spell lists.
#
# ```
# POWER = {
#     'Fireball': 50,
#     'Lightning bolt': 40,
#     'Magic arrow': 10,
#     'Black Tentacles': 25,
#     'Contagion': 45
# }
#
# gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball',
#            'Magic arrow', 'Lightning bolt', 'Fireball', 'Fireball', 'Fireball']
# saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles',
#            'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']
# ```
#
# Good luck!

# %%
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# variables

POWER = {'Fireball': 50, 'Lightning bolt': 40, 'Magic arrow': 10, 'Black Tentacles': 25, 'Contagion': 45}

gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball', 
           'Magic arrow', 'Lightning bolt', 'Fireball', 'Magic arrow', 'Fireball']
saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles', 
           'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']

print(POWER.values())
print(POWER.keys())

for i in gandalf:
    print(i, end= ", ")
    
milista = [50, 40, 10, 25, 45]
Fireball, Lightning_bolt, Magic_arrow, Black_Tentacles, Contagion = milista

print(Fireball, Lightning_bolt, Lightning_bolt, Magic_arrow, Fireball, Magic_arrow, Lightning_bolt, Fireball, Magic_arrow, Fireball)
print()
# Out:
# dict_values([50, 40, 10, 25, 45])
# dict_keys(['Fireball', 'Lightning bolt', 'Magic arrow', 'Black Tentacles', 'Contagion'])
# Fireball, Lightning bolt, Lightning bolt, Magic arrow, Fireball, Magic arrow, Lightning bolt, Fireball, Magic arrow, Fireball, 50 40 40 10 50 10 40 50 10 50

# %%
# Assign spell power lists to variables

# %% [markdown]
# **Expected output**:
# ```
# ([50, 40, 40, 10, 50, 10, 40, 50, 10, 50],
#  [45, 45, 25, 50, 25, 40, 10, 45, 10, 10])
#  ```

# %%
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.



# Execution of spell clashes

# check clashes

# check for 3 wins in a row

# check the winner

# count sum of clashes

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %%
# 3. Average of each of the spell lists.

# %% [markdown]
# **Expected output**:
# ```
# 35.0
# 30.5
# ```

# %%
# 4. Standard deviation of each of the spell lists.

# %% [markdown]
# **Expected output**:
# ```
# 16.881943016134134
# 15.56438241627338
# ```
