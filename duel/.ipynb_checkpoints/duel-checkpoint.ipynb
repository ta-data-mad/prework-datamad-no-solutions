# %% [markdown]
# # Duel of sorcerers
# ## Intro
# You are witnessing an epic battle between two powerful sorcerers: Gandalf and Saruman. Each sorcerer has 10 spells of variable power in their mind and they are going to throw them one after the other. The winner of the duel will be the one who wins more of those clashes between spells. Spells are represented as a list of 10 integers whose value equals the power of the spell.
# ```
# gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
# saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]
# ```
# For example:
# 1. The first clash is won by Saruman: 10 against 23, wins 23
# 2. The second clash wins Saruman: 11 against 66, wins 66
# 3. etc.
#
#
# You will create two variables, one for each sorcerer, where the sum of clashes won will be stored. Depending on which variable is greater at the end of the duel, you will show one of the following three results on the screen:
# * Gandalf wins
# * Saruman wins
# * Tie
#
# <img src="images/content_lightning_bolt_big.jpg" width="400">
#
# ## LINKS:
# * zip: https://www.programiz.com/python-programming/methods/built-in/zip

# %% [markdown]
# ## Solution

# %%
# Assign spell power lists to variables
gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]

# %%
# Assign 0 to each variable that stores the victories
gandalf_wins = 0
saruman_wins = 0
ties = 0

# %%
# Execution of spell clashes
gandalf_wins = 0
saruman_wins = 0
ties = 0
result = zip()
result = zip(gandalf, saruman)
result_list = list(result)

if result_list [0][0] > result_list[0][1]: 
    gandalf_wins += 1
elif result_list [0][0] < result_list[0][1]:
    saruman_wins += 1
else: 
    ties += 1

if result_list [1][0] > result_list[1][1]: 
    gandalf_wins += 1
elif result_list [1][0] < result_list[1][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [2][0] > result_list[2][1]: 
    gandalf_wins += 1
elif result_list [2][0] < result_list[2][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [3][0] > result_list[3][1]: 
    gandalf_wins += 1
elif result_list [3][0] < result_list[3][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [4][0] > result_list[4][1]: 
    gandalf_wins += 1
elif result_list [4][0] < result_list[0][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [5][0] > result_list[5][1]: 
    gandalf_wins += 1
elif result_list [5][0] < result_list[5][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [6][0] > result_list[6][1]: 
    gandalf_wins += 1
elif result_list [6][0] < result_list[6][1]:
    saruman_wins += 1
else: 
    ties += 1

if result_list [7][0] > result_list[7][1]: 
    gandalf_wins += 1
elif result_list [7][0] < result_list[7][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [8][0] > result_list[8][1]: 
    gandalf_wins += 1
elif result_list [8][0] < result_list[8][1]:
    saruman_wins += 1
else: 
    ties += 1

if result_list [9][0] > result_list[9][1]: 
    gandalf_wins += 1
elif result_list [9][0] < result_list[9][1]:
    saruman_wins += 1
else: 
    ties += 1
    
print(gandalf_wins)
print(saruman_wins)
# Out:
# 6
# 4

# %% [markdown]
# **Expected output**:
# ```
# 6
# 4
# ```

# %%
# We check who has won, do not forget the possibility of a draw.
# Print the result based on the winner.
if gandalf_wins > saruman_wins: 
    print("Gandalf wins")
elif gandalf_wins < saruman_wins:
    print("Saruman wins")
else: 
    print("It´s a tie")
# Out:
# Gandalf wins

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %% [markdown]
# ## Goals
#
# 1. Treatment of lists
# 2. Use of **for loop**
# 3. Use of conditional **if-elif-else**
# 4. Use of the functions **range(), len()**
# 5. print()
# 6. zip()

# %% [markdown]
# ## Bonus
#
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.
# 3. Average of each of the spell lists.
# 4. Standard deviation of each of the spell lists.
#
# ```
# POWER = {
#     'Fireball': 50,
#     'Lightning bolt': 40,
#     'Magic arrow': 10,
#     'Black Tentacles': 25,
#     'Contagion': 45
# }
#
# gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball',
#            'Magic arrow', 'Lightning bolt', 'Fireball', 'Fireball', 'Fireball']
# saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles',
#            'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']
# ```
#
# Good luck!

# %%
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# variables

POWER = {
    'Fireball': 50, 
    'Lightning bolt': 40, 
    'Magic arrow': 10, 
    'Black Tentacles': 25, 
    'Contagion': 45
}

gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball', 
           'Magic arrow', 'Lightning bolt', 'Fireball', 'Magic arrow', 'Fireball']
saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles', 
           'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']

# %%
# Assign spell power lists to variables
power = {
    'Fireball': 50, 
    'Lightning bolt': 40, 
    'Magic arrow': 10, 
    'Black Tentacles': 25, 
    'Contagion': 45
}

gandalf_list = [power["Fireball"], power["Lightning bolt"], power["Lightning bolt"], power["Magic arrow"], power["Fireball"], power["Magic arrow"], power["Lightning bolt"], power["Fireball"], power["Magic arrow"], power["Fireball"]] 
print(gandalf_list)
saruman_list = [power['Contagion'], power['Contagion'], power["Black Tentacles"], power['Fireball'], power['Black Tentacles'], power['Lightning bolt'], power['Magic arrow'], power['Contagion'], power['Magic arrow'], power['Magic arrow']]
print(saruman_list)
# Out:
# [50, 40, 40, 10, 50, 10, 40, 50, 10, 50]
# [45, 45, 25, 50, 25, 40, 10, 45, 10, 10]

# %% [markdown]
# **Expected output**:
# ```
# ([50, 40, 40, 10, 50, 10, 40, 50, 10, 50],
#  [45, 45, 25, 50, 25, 40, 10, 45, 10, 10])
#  ```

# %%
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.

# Execution of spell clashes
gandalf_wins = 0
saruman_wins = 0
ties = 0
result = zip()
result = zip(gandalf_list, saruman_list)
result_list = list(result)
print(result_list)
# check clashes
if result_list [0][0] > result_list[0][1]: 
    gandalf_wins += 1
elif result_list [0][0] < result_list[0][1]:
    saruman_wins += 1
else: 
    ties += 1

if result_list [1][0] > result_list[1][1]: 
    gandalf_wins += 1
elif result_list [1][0] < result_list[1][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [2][0] > result_list[2][1]: 
    gandalf_wins += 1
elif result_list [2][0] < result_list[2][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [3][0] > result_list[3][1]: 
    gandalf_wins += 1
elif result_list [3][0] < result_list[3][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [4][0] > result_list[4][1]: 
    gandalf_wins += 1
elif result_list [4][0] < result_list[0][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [5][0] > result_list[5][1]: 
    gandalf_wins += 1
elif result_list [5][0] < result_list[5][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [6][0] > result_list[6][1]: 
    gandalf_wins += 1
elif result_list [6][0] < result_list[6][1]:
    saruman_wins += 1
else: 
    ties += 1

if result_list [7][0] > result_list[7][1]: 
    gandalf_wins += 1
elif result_list [7][0] < result_list[7][1]:
    saruman_wins += 1
else: 
    ties += 1
    
if result_list [8][0] > result_list[8][1]: 
    gandalf_wins += 1
elif result_list [8][0] < result_list[8][1]:
    saruman_wins += 1
else: 
    ties += 1

if result_list [9][0] > result_list[9][1]: 
    gandalf_wins += 1
elif result_list [9][0] < result_list[9][1]:
    saruman_wins += 1
else: 
    ties += 1

print("Gandalf =", gandalf_wins)
print("Ties =", ties)
print("Saruman =", saruman_wins)



# check for 3 wins in a row
gandalf_wins_row = 0
saruman_wins_row = 0
while gandalf_wins_row < 3 and saruman_wins_row < 3:
    if result_list [0][0] > result_list[0][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [0][0] < result_list[0][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1

    if result_list [1][0] > result_list[1][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [1][0] < result_list[1][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1
        
    if result_list [2][0] > result_list[2][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [2][0] < result_list[2][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1
    
    if result_list [3][0] > result_list[3][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [3][0] < result_list[3][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1
    
    if result_list [4][0] > result_list[4][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [4][0] < result_list[4][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1
    
    if result_list [5][0] > result_list[5][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [5][0] < result_list[5][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1
        
    if result_list [6][0] > result_list[6][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [6][0] < result_list[6][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1
        
    if result_list [7][0] > result_list[7][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [7][0] < result_list[7][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1
    
    if result_list [8][0] > result_list[8][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [8][0] < result_list[8][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1
    
    if result_list [9][0] > result_list[9][1]: 
        gandalf_wins_row += 1
        saruman_wins_row = 0
    elif result_list [9][0] < result_list[9][1]:
        saruman_wins_row += 1
        gandalf_wins_row = 0
    else: 
        ties += 1
        
    if gandalf_wins_row >= 3:
        print("Gandalf has won", gandalf_wins_row, "in a row, therefore he is the winner")
    elif saruman_wins_row >= 3:
        print("Saruman has won", gandalf_wins_row, "in a row, therefore he is the winner")
    else: 
        print("Nobody has won enough clashes in a row")

# check the winner



# count sum of clashes
# Out:
# [(50, 45), (40, 45), (40, 25), (10, 50), (50, 25), (10, 40), (40, 10), (50, 45), (10, 10), (50, 10)]
# Gandalf = 6
# Ties = 1
# Saruman = 3
# Gandalf has won 3 in a row, therefore he is the winner

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %%
# 3. Average of each of the spell lists.
average_gandalf = sum(gandalf_list)/len(gandalf_list)
print(average_gandalf)
average_saruman = sum(saruman_list)/len(saruman_list)
print(average_saruman)
# Out:
# 35.0
# 30.5

# %% [markdown]
# **Expected output**:
# ```
# 35.0
# 30.5
# ```

# %%
# 4. Standard deviation of each of the spell lists.

#MÉTODO 1 
import math
sumatorio = (gandalf_list[0] - average_gandalf)**2 + (gandalf_list[1] - average_gandalf)**2 + (gandalf_list[2] - average_gandalf)**2 + (gandalf_list[3] - average_gandalf)**2 + (gandalf_list[4] - average_gandalf)**2 + (gandalf_list[5] - average_gandalf)**2 + (gandalf_list[6] - average_gandalf)**2 + (gandalf_list[7] - average_gandalf)**2 + (gandalf_list[8] - average_gandalf)**2 + (gandalf_list[9] - average_gandalf)**2
division = sumatorio/(len(gandalf_list) - 1)
standard_deviation_gandalf = math.sqrt(division)
print(standard_deviation_gandalf)

sumatorio = (saruman_list[0] - average_saruman)**2 + (saruman_list[1] - average_saruman)**2 + (saruman_list[2] - average_saruman)**2 + (saruman_list[3] - average_saruman)**2 + (saruman_list[4] - average_saruman)**2 + (saruman_list[5] - average_saruman)**2 + (saruman_list[6] - average_saruman)**2 + (saruman_list[7] - average_saruman)**2 + (saruman_list[8] - average_saruman)**2 + (saruman_list[9] - average_saruman)**2
division = sumatorio/(len(saruman_list) - 1)
standard_deviation_saruman = math.sqrt(division)
print(standard_deviation_saruman)

#MÉTODO 2
import statistics 

print(statistics.stdev(gandalf_list))
print(statistics.stdev(saruman_list))
# Out:
# 17.795130420052185
# 16.40629960309962
# 17.795130420052185
# 16.40629960309962

# %% [markdown]
# **Expected output**:
# ```
# 16.881943016134134
# 15.56438241627338
# ```
