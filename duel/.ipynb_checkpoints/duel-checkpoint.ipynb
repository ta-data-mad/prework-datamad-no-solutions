# %% [markdown]
# # Duel of sorcerers
# ## Intro
# You are witnessing an epic battle between two powerful sorcerers: Gandalf and Saruman. Each sorcerer has 10 spells of variable power in their mind and they are going to throw them one after the other. The winner of the duel will be the one who wins more of those clashes between spells. Spells are represented as a list of 10 integers whose value equals the power of the spell.
# ```
# gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
# saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]
# ```
# For example:
# 1. The first clash is won by Saruman: 10 against 23, wins 23
# 2. The second clash wins Saruman: 11 against 66, wins 66
# 3. etc.
#
#
# You will create two variables, one for each sorcerer, where the sum of clashes won will be stored. Depending on which variable is greater at the end of the duel, you will show one of the following three results on the screen:
# * Gandalf wins
# * Saruman wins
# * Tie
#
# <img src="images/content_lightning_bolt_big.jpg" width="400">
#
# ## LINKS:
# * zip: https://www.programiz.com/python-programming/methods/built-in/zip

# %% [markdown]
# ## Solution

# %%
# Assign spell power lists to variables
gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]

# %%
# Assign 0 to each variable that stores the victories
gandalf_wins = 0
saruman_wins = 0

# %%
# Execution of spell clashes
for i in range (0,10):
    if gandalf [i] > saruman [i]:
         gandalf_wins +=1
    else:
        saruman_wins +=1
        

print (gandalf_wins)
print (saruman_wins)
# Out:
# 6
# 4

# %% [markdown]
# **Expected output**:
# ```
# 6
# 4
# ```

# %%
if gandalf_wins > saruman_wins:
    print ("Gandalf gana la batalla")
elif saruman_wins > gandalf_wins:
    print ("F for Gandalf")
else: 
    print ("Empate")
# Out:
# Gandalf gana la batalla

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %% [markdown]
# ## Goals
#
# 1. Treatment of lists
# 2. Use of **for loop**
# 3. Use of conditional **if-elif-else**
# 4. Use of the functions **range(), len()**
# 5. print()
# 6. zip()

# %% [markdown]
# ## Bonus
#
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.
# 3. Average of each of the spell lists.
# 4. Standard deviation of each of the spell lists.
#
# ```
# POWER = {
#     'Fireball': 50,
#     'Lightning bolt': 40,
#     'Magic arrow': 10,
#     'Black Tentacles': 25,
#     'Contagion': 45
# }
#
# gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball',
#            'Magic arrow', 'Lightning bolt', 'Fireball', 'Fireball', 'Fireball']
# saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles',
#            'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']
# ```
#
# Good luck!

# %%
# 1. Spells now have a name and there is a dictionary that relates that name to a power.
# variables
import numpy as np


POWER = {
    'Fireball': 50, 
    'Lightning bolt': 40, 
    'Magic arrow': 10, 
    'Black Tentacles': 25, 
    'Contagion': 45
}

gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball', 
           'Magic arrow', 'Lightning bolt', 'Fireball', 'Magic arrow', 'Fireball']
saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles', 
           'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']

# %%
# Assign spell power lists to variables
spells = 0
gandalf_power = 0
saruman_power = 0
gandalf_wins = 0
saruman_wins = 0
lista_power_g = []
lista_power_s = []

for i in range (0,10):
    gandalf_power = POWER[gandalf[i]]
    saruman_power = POWER[saruman[i]]
    lista_power_g.append(gandalf_power)
    lista_power_s.append(saruman_power)
    if gandalf_power > saruman_power and saruman_wins < 3 and gandalf_wins < 3: 
        gandalf_wins +=1
        saruman_wins = 0
    elif saruman_power > gandalf_power and saruman_wins < 3 and gandalf_wins < 3:
        saruman_wins +=1
        gandalf_wins = 0
print (lista_power_g)
print (lista_power_s)
# Out:
# [50, 40, 40, 10, 50, 10, 40, 50, 10, 50]
# [45, 45, 25, 50, 25, 40, 10, 45, 10, 10]

# %% [markdown]
# **Expected output**:
# ```
# ([50, 40, 40, 10, 50, 10, 40, 50, 10, 50],
#  [45, 45, 25, 50, 25, 40, 10, 45, 10, 10])
#  ```

# %%
# 2. A sorcerer wins if he succeeds in winning 3 spell clashes in a row.



# Execution of spell clashes

# check clashes

# check for 3 wins in a row

# check the winner

# count sum of clashes

if gandalf_wins > 2:
    print ("Gandalf gana la batalla")
elif saruman_wins > 2:
    print ("Saruman gana la batalla")
else:
    if saruman_wins > gandalf_wins:
        print ("Saruman gana por agotamiento")
    else:
        print ("GandalF gana por aburrimiento")
# Out:
# Gandalf gana la batalla

# %% [markdown]
# **Expected output**:
# ```
# Gandalf wins
# ```

# %%
# 3. Average of each of the spell lists.
print('La media de poder de Gandalf es: %f' %(np.mean(lista_power_g)))
print('La media de poder de Saruman es: %f' %(np.mean(lista_power_s)))
# Out:
# La media de poder de Gandalf es: 35.000000
# La media de poder de Saruman es: 30.500000

# %% [markdown]
# **Expected output**:
# ```
# 35.0
# 30.5
# ```

# %%
# 4. Standard deviation of each of the spell lists.

print('La desviacion tipica de poder de Gandalf es: %f' %(np.std(lista_power_g)))
print('La desviacion tipica de poder de Saruman es: %f' %(np.std(lista_power_s)))
# Out:
# La desviacion tipica de poder de Gandalf es: 16.881943
# La desviacion tipica de poder de Saruman es: 15.564382

# %% [markdown]
# **Expected output**:
# ```
# 16.881943016134134
# 15.56438241627338
# ```
