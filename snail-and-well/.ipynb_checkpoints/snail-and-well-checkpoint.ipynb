# %% [markdown]
# # Snail and well
#
# A snail falls at the bottom of a 125 cm well. Each day the snail rises 30 cm. But at night, while sleeping, slides 20 cm because the walls are wet. How many days does it take to escape from the well?
#
# TIP: http://puzzles.nigelcoldwell.co.uk/sixtytwo.htm

# %% [markdown]
# ## Solución

# %%
# Assign problem data to variables with representative names
# well height, daily advance, night retreat, accumulated distance

well_height = 125
daily_distance = 30
nightly_distance = -20
snail_position = 0

# Assign 0 to the variable that represents the solution
result = 0

# Write the code that solves the problem

while well_height >= snail_position:
    snail_position = snail_position + daily_distance 
    result += 1
    if well_height >= snail_position:
        snail_position = snail_position + nightly_distance

# Print the result with print('Days =', days)
print (result)
# Out:
# 11

# %% [markdown]
# **Expected output**:
# ```
# Days = 11
# ```

# %% [markdown]
# ## Goals
#
# 1. Treatment of variables
# 2. Use of loop **while**
# 3. Use of conditional **if-else**
# 4. Print in console

# %% [markdown]
# ## Bonus
# The distance traveled by the snail is now defined by a list.
# ```
# advance_cm = [30, 21, 33, 77, 44, 45, 23, 45, 12, 34, 55]
# ```
# How long does it take to raise the well?
#
# What is its maximum displacement in one day? And its minimum?
#
# What is its average speed during the day?
#
# What is the standard deviation of its displacement during the day?

# %%
# Assign problem data to variables with representative names
# well height, daily advance, night retreat, accumulated distance

well_height = 125
advance_cm = [30, 21, 33, 77, 44, 45, 23, 45, 12, 34, 55]
nightly_distance = -20
snail_position = 0

# Assign 0 to the variable that represents the solution

result = 0
# Write the code that solves the problem

while well_height >= snail_position:
    snail_position = snail_position + advance_cm[result]
    result += 1
    if well_height >= snail_position:
        snail_position = snail_position + nightly_distance

# Print the result with print('Days =', days)
print(result)
# Out:
# 6

# %% [markdown]
# **Expected output**:
# ```
# Days = 6
# ```

# %%
# What is its maximum displacement in a day? And its minimum?
import numpy as np

max = np.max(advance_cm)
min = np.min(advance_cm)
print('Max: ' + str(max) + " \nMin: " + str(min))
# Out:
# Max: 77
# Min: 12

# %% [markdown]
# **Expected output**:
# ```
# 77 12
# ```

# %%
# What is its average progress?
import statistics 
average = statistics.mean(advance_cm) 
print(average)
# Out:
# 38.09090909090909

# %% [markdown]
# **Expected output**:
# ```
# 38.09090909090909
# ```

# %%
# What is the standard deviation of your displacement during the day?
import statistics 
standard_deviation = statistics.pstdev(advance_cm) 
print(standard_deviation)
# Out:
# 17.159437082600803

# %% [markdown]
# **Expected output**:
# ```
# 17.159437082600803
# ```
