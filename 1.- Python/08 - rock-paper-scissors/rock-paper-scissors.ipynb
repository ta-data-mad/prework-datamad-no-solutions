# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

from random import choice

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
options = ["stone","paper","scissors"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

max_number_games = 3

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

games_to_win = int((max_number_games + 1)/2) #or round(max_number_games/2 + 1)

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def random_choice():
    return choice(options)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def ask_your_choice():
    choice = ""
    while choice not in options:
        print("Which one is your choice: 'stone', 'paper' or 'scissors'?")
        choice = input()
    return choice

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def combat(player,computer):
    if player == "stone":
        if computer == "stone":
            print("Tie")
            return 0
        if computer == "paper":
            print("Computer wins")
            return 1
        if computer == "scissors":
            print("Player wins")
            return 2
    
    if player == "paper":
        if computer == "stone":
            print("Player wins")
            return 2
        if computer == "paper":
            print("Tie")
            return 0
        if computer == "scissors":
            print("Computer wins")
            return 1
    
    if player == "scissors":
        if computer == "stone":
            print("Computer wins")
            return 1
        if computer == "paper":
            print("Player wins")
            return 2
        if computer == "scissors":
            print("Tie")
            return 0

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def state_of_the_game(player_choice,computer_choice,player_wins,computer_wins):
    print("Player chose: ", player_choice, "Computer chose: ", computer_choice)
    print("Player accumulated wins: ", player_wins, "Computer accumulated wins: ",computer_wins)

# Create two variables that accumulate the wins of each participant
player_accumulate_wins = 0
computer_accumulate_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while player_accumulate_wins < games_to_win and computer_accumulate_wins < games_to_win:
    my_choice = ask_your_choice()
    computer_choice = random_choice()
    result = combat(my_choice, computer_choice)
    if result == 1:
        computer_accumulate_wins+=1
    if result == 2:
        player_accumulate_wins+=1
    state_of_the_game(my_choice, computer_choice, player_accumulate_wins, computer_accumulate_wins)
# Print by console the winner of the game based on who has more accumulated wins

if player_accumulate_wins > computer_accumulate_wins:
    print("Yayyy! Congratulations, player is the winner")
else:
    print("Oh no! computer is the winner")
# Out:
# Which one is your choice: 'stone', 'paper' or 'scissors'?
# paper
# Tie
# Player chose:  paper Computer chose:  paper
# Player accumulated wins:  0 Computer accumulated wins:  0
# Which one is your choice: 'stone', 'paper' or 'scissors'?
# paper
# Tie
# Player chose:  paper Computer chose:  paper
# Player accumulated wins:  0 Computer accumulated wins:  0
# Which one is your choice: 'stone', 'paper' or 'scissors'?
# paper
# Player wins
# Player chose:  paper Computer chose:  stone
# Player accumulated wins:  1 Computer accumulated wins:  0
# Which one is your choice: 'stone', 'paper' or 'scissors'?
# paper
# Tie
# Player chose:  paper Computer chose:  paper
# Player accumulated wins:  1 Computer accumulated wins:  0
# Which one is your choice: 'stone', 'paper' or 'scissors'?
# paper
# Player wins
# Player chose:  paper Computer chose:  stone
# Player accumulated wins:  2 Computer accumulated wins:  0
# Yayyy! Congratulations, player is the winner

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module

from random import choice

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking

def ask_odd_number():
    choice = 0
    while choice%2 == 0:
        print("Choose an odd number: ")
        try:
            choice = int(input())
        except:
            print("Please enter and odd number")
    return choice

# Assign a list of 5 possible options.
bonus_options = ["stone","paper","scissors","lizard","spock"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
bonus_max_number_games = ask_odd_number()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
games_to_win = int((bonus_max_number_games + 1)/2)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def bonus_random_choice():
    return choice(bonus_options)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

def bonus_ask_your_choice():
    choice = ""
    while choice not in bonus_options:
        print("Which one is your choice: 'stone', 'paper', 'scissors', 'lizard' or 'spock'?")
        choice = input()
    return choice
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options


def bonus_combat(player,computer):
    if player == "stone":
        if computer == "stone":
            print("Tie")
            return 0
        if computer == "paper":
            print("Computer wins")
            return 1
        if computer == "scissors":
            print("Player wins")
            return 2
        if computer == "spock":
            print("Computer wins")
            return 1
        if computer == "lizard":
            print("Player wins")
            return 2
    
    if player == "paper":
        if computer == "stone":
            print("Player wins")
            return 2
        if computer == "paper":
            print("Tie")
            return 0
        if computer == "scissors":
            print("Computer wins")
            return 1
        if computer == "spock":
            print("Player wins")
            return 2
        if computer == "lizard":
            print("Computer wins")
            return 1
    
    if player == "scissors":
        if computer == "stone":
            print("Computer wins")
            return 1
        if computer == "paper":
            print("Player wins")
            return 2
        if computer == "scissors":
            print("Tie")
            return 0
        if computer == "spock":
            print("Computer wins")
            return 1
        if computer == "lizard":
            print("Player wins")
            return 2
        
    if player == "spock":
        if computer == "stone":
            print("Player wins")
            return 2
        if computer == "paper":
            print("Computer wins")
            return 1
        if computer == "scissors":
            print("Player wins")
            return 2
        if computer == "spock":
            print("Tie")
            return 0
        if computer == "lizard":
            print("Computer wins")
            return 1

    if player == "lizard":
        if computer == "stone":
            print("Computer wins")
            return 1
        if computer == "paper":
            print("Player wins")
            return 2
        if computer == "scissors":
            print("Computer wins")
            return 1
        if computer == "spock":
            print("Player wins")
            return 2
        if computer == "lizard":
            print("Tie")
            return 0

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def bonus_state_of_the_game(player_choice,computer_choice,player_wins,computer_wins):
    print("Player chose: ", player_choice, "Computer chose: ", computer_choice)
    print("Player accumulated wins: ", player_wins, "Computer accumulated wins: ",computer_wins)
    
# Create two variables that accumulate the wins of each participant
player_accumulate_wins = 0
computer_accumulate_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while player_accumulate_wins < games_to_win and computer_accumulate_wins < games_to_win:
    my_choice = bonus_ask_your_choice()
    computer_choice = bonus_random_choice()
    result = bonus_combat(my_choice, computer_choice)
    if result == 1:
        computer_accumulate_wins+=1
    if result == 2:
        player_accumulate_wins+=1
    state_of_the_game(my_choice, computer_choice, player_accumulate_wins, computer_accumulate_wins)
    
# Print by console the winner of the game based on who has more accumulated wins

if player_accumulate_wins > computer_accumulate_wins:
    print("Yayyy! Congratulations, player is the winner")
else:
    print("Oh no! computer is the winner")
# Out:
# Choose an odd number:
# w
# Please enter and odd number
# Choose an odd number:
# 1
# Which one is your choice: 'stone', 'paper', 'scissors', 'lizard' or 'spock'?
# stone
# Player wins
# Player chose:  stone Computer chose:  scissors
# Player accumulated wins:  1 Computer accumulated wins:  0
# Yayyy! Congratulations, player is the winner

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
