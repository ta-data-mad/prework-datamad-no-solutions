# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random 

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
possible_hand = ['stone', 'paper', 'scissors']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
maxGames = 7

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
victoriesToWin = (maxGames // 2 + 1)

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def random_hand():
    machine = random.choice(possible_hand)
    return machine

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def humanHand():
    human = input('What is your choice? ')
    human = human.lower()
    while (human != 'stone') and (human != 'paper') and (human != 'scissors'):
        human = input('You have to choose either stone, paper or scissors ')
        human = human.lower()
    return human



# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def combat():
    machine = random_hand()
    human = humanHand()
    if human == 'stone':
        if machine == 'stone':
            return 0
        elif machine == 'paper':
            return 1
        else:
            return 2
    elif human == 'paper':
        if machine == 'stone':
            return 2
        elif machine == 'paper':
            return 0
        else:
            return 1
    elif human == 'scissors':
        if machine == 'stone':
            return 1
        elif machine == 'paper':
            return 2
        else:
            return 0
        
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def choice_state():
    print('Human won: ', human_Win, 'games')
    print('Machine won: ', machine_Win, 'games')
    print('Tied games: ', tie_Game)
# Create two variables that accumulate the wins of each participant
machine_Win = 0
human_Win = 0
tie_Game = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while human_Win < victoriesToWin and machine_Win < victoriesToWin:
    result = combat()
    if result == 1:
        machine_Win += 1
    elif result == 2:
        human_Win += 1
    else:
        tie_Game += 1
    choice_state()
if human_Win == victoriesToWin:
    print('Human won', human_Win, '-', machine_Win) 
elif machine_Win == victoriesToWin:
    print('Machine won:', machine_Win, '-', human_Win)
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# What is your choice? ston
# You have to choose either stone, paper or scissors stone
# Human won:  1 games
# Machine won:  0 games
# Tied games:  0
# What is your choice? stone
# Human won:  1 games
# Machine won:  1 games
# Tied games:  0
# What is your choice? stone
# Human won:  1 games
# Machine won:  2 games
# Tied games:  0
# What is your choice? stone
# Human won:  2 games
# Machine won:  2 games
# Tied games:  0
# What is your choice? stone
# Human won:  2 games
# Machine won:  3 games
# Tied games:  0
# What is your choice? stone
# Human won:  2 games
# Machine won:  4 games
# Tied games:  0
# Machine won: 4 - 2

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random 

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def ask_odd():
    while True:
        try:
            odd_num = int(input('Give me an odd number '))       
        except ValueError:
            print("Not an integer! Try again.")
            continue
        else:
            if odd_num % 2 != 0:
                return odd_num
                break 
            else:
                continue

# Assign a list of 5 possible options.
possible_hand = ['stone', 'paper', 'scissors', 'lizard', 'spock']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
maxGames = ask_odd()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
victoriesToWin = (maxGames // 2 + 1)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def random_hand():
    machine = random.choice(possible_hand)
    return machine

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def humanHand():
    human = input('What is your choice? ')
    human = human.lower()
    while (human != 'stone') and (human != 'paper') and (human != 'scissors') and (human != 'lizard') and (human != 'spock'):
        human = input('You have to choose either stone, paper, scissors, lizard or spock ')
        human = human.lower()
    return human

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def combat():
    machine = random_hand()
    human = humanHand()
    if human == 'stone':
        if machine == 'stone':
            return 0
        elif machine == 'paper' or machine == 'spock':
            return 1
        else:
            return 2
    elif human == 'paper':
        if machine == 'stone' or machine == 'spock':
            return 2
        elif machine == 'paper':
            return 0
        else:
            return 1
    elif human == 'scissors':
        if machine == 'stone' or machine == 'spock':
            return 1
        elif machine == 'paper':
            return 2
        else:
            return 0
    elif human == 'lizard':
        if machine == 'paper' or machine == 'spock':
            return 2
        elif machine == 'scissor' or machine == 'stone':
            return 1
        else:
            return 0
    elif human == 'spock':
        if machine == 'spock':
            return 0
        elif machine == 'rock' or machine == 'scissors':
            return 2
        else:
            return 1
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def choice_state():
    print('Human won: ', human_Win, 'games')
    print('Machine won: ', machine_Win, 'games')
    print('Tied games: ', tie_Game)
    
# Create two variables that accumulate the wins of each participant
human_Win = 0
machine_Win = 0
tie_Game = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while human_Win < victoriesToWin and machine_Win < victoriesToWin:
    result = combat()
    if result == 1:
        machine_Win += 1
    elif result == 2:
        human_Win += 1
    else:
        tie_Game += 1
    choice_state()
   
    
# Print by console the winner of the game based on who has more accumulated wins
if human_Win == victoriesToWin:
  print('Human won', human_Win, '-', machine_Win) 
elif machine_Win == victoriesToWin:
  print('Machine won:', machine_Win, '-', human_Win)
# Out:
# Give me an odd number 2
# Give me an odd number 3
# What is your choice? spock
# Human won:  0 games
# Machine won:  0 games
# Tied games:  1
# What is your choice? spock
# Human won:  0 games
# Machine won:  0 games
# Tied games:  2
# What is your choice? spock
# Human won:  0 games
# Machine won:  1 games
# Tied games:  2
# What is your choice? spock
# Human won:  0 games
# Machine won:  2 games
# Tied games:  2
# Machine won: 2 - 0

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
