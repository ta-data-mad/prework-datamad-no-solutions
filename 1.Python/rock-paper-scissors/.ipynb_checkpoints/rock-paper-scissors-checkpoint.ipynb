# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

from random import choice

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

posiblesjugadas = ["Piedra", "Papel", "Tijeras"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

juegosmax = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

juegosganar = int((juegosmax+1)/2)

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def jugadarandom():
    return choice(posiblesjugadas)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def jugadahumano():
    eleccion = input ("Elige una jugada: \n")
    
    while eleccion not in posiblesjugadas:
        eleccion = input ("Es Piedra, Papel o Tijeras, intentalo otra vez: \n")

    return eleccion
        
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def combate(eleccion, comp):
    
    if (eleccion == "Piedra"):
        if (comp == "Papel"):
            print("Has perdido")
            return 1
        elif (comp == "Tijeras"):
            print ("Has ganado")
            return 2
        else:
            print ("Empate")
            return 0

    if (eleccion == "Papel"):
        if (comp == "Tijeras"):
            print("Has perdido")
            return 1
        elif (comp == "Piedra"):
            print ("Has ganado")
            return 2
        else:
            print ("Empate")
            return 0


    if (eleccion == "Tijeras"):
        if (comp == "Piedra"):
            print("Has perdido")
            return 1
        elif (comp == "Papel"):
            print ("Has ganado")
            return 2
        else:
            print ("Empate")
            return 0


    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def gamestate(eleccion, comp, vhumano, vPC):
    print ("Eleccion humano:", eleccion,"Eleccion PC:", comp,"Victorias humano:", vhumano, "Victorias PC:", vPC)
    
# Create two variables that accumulate the wins of each participant

victoriasPC = 0
victoriasHumano = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while max(victoriasHumano, victoriasPC) < juegosganar:
    eleccion = jugadahumano()
    comp = jugadarandom()
    
    result = combate(eleccion, comp)
    if result == 2:
        victoriasHumano += 1
        gamestate(eleccion, comp, victoriasHumano, victoriasPC)
    elif result == 1:
        victoriasPC += 1
        gamestate(eleccion, comp, victoriasHumano, victoriasPC)
    else:
        print("Doble", comp, "¡Empate!")

    
# Print by console the winner of the game based on who has more accumulated wins
if victoriasHumano > victoriasPC:
    print("¡Has ganado!")
else:
    print("¡Has perdido!")

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

from random import choice

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

posiblesjugadas = ["Piedra", "Papel", "Tijeras", "Lagarto", "Spock"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

juegosmax = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

juegosganar = int((juegosmax+1)/2)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.

def jugadarandom():
    return choice(posiblesjugadas)

# Define a function that asks your choice
# you should only allow one of the 5 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def jugadahumano():
    eleccion = input ("Elige una jugada: \n")
    
    while eleccion not in posiblesjugadas:
        eleccion = input ("Es Piedra, Papel, Tijeras, Lagarto o Spock, intentalo otra vez: \n")

    return eleccion
        
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def combate(eleccion, comp):
    
    if (eleccion == "Piedra"):
        if (comp in ["Papel", "Spock"]):
            print("Has perdido")
            return 1
        elif (comp in ["Tijeras", "Lagarto"]):
            print ("Has ganado")
            return 2
        else:
            print ("Empate")
            return 0

    if (eleccion == "Papel"):
        if (comp in ["Tijeras", "Lagarto"]):
            print("Has perdido")
            return 1
        elif (comp in ["Piedra", "Spock"]):
            print ("Has ganado")
            return 2
        else:
            print ("Empate")
            return 0


    if (eleccion == "Tijeras"):
        if (comp in ["Piedra", "Spock"]):
            print("Has perdido")
            return 1
        elif (comp in ["Papel", "Lagarto"]):
            print ("Has ganado")
            return 2
        else:
            print ("Empate")
            return 0

    if (eleccion == "Lagarto"):
        if (comp in ["Piedra", "Tijeras"]):
            print("Has perdido")
            return 1
        elif (comp in ["Papel", "Spock"]):
            print ("Has ganado")
            return 2
        else:
            print ("Empate")
            return 0

    if (eleccion == "Spock"):
        if (comp in ["Lagarto", "Papel"]):
            print("Has perdido")
            return 1
        elif (comp in ["Piedra", "Tijeras"]):
            print ("Has ganado")
            return 2
        else:
            print ("Empate")
            return 0

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def gamestate(eleccion, comp, vhumano, vPC):
    print ("Eleccion humano:", eleccion,"Eleccion PC:", comp,"Victorias humano:", vhumano, "Victorias PC:", vPC)
    
# Create two variables that accumulate the wins of each participant

victoriasPC = 0
victoriasHumano = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while max(victoriasHumano, victoriasPC) < juegosganar:
    eleccion = jugadahumano()
    comp = jugadarandom()
    
    result = combate(eleccion, comp)
    if result == 2:
        victoriasHumano += 1
        gamestate(eleccion, comp, victoriasHumano, victoriasPC)
    elif result == 1:
        victoriasPC += 1
        gamestate(eleccion, comp, victoriasHumano, victoriasPC)
    else:
        print("Doble", comp, "¡Empate!")

    
# Print by console the winner of the game based on who has more accumulated wins
if victoriasHumano > victoriasPC:
    print("¡Has ganado!")
else:
    print("¡Has perdido!")

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
