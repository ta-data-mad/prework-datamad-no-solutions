# %% [markdown]
# # Lyrics
# ## Intro
# This exercise is simple. You are going to create a code that writes the lyrics of a famous song. **The shorter your code is, the better**. Although it may seem a bit silly, it is important that you learn to automate repetitive tasks or that there are few changes between them.
#
# <img src="./images/babyshark.jpeg" width="400">
#
# ## Song
#
# ```
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark!
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark!
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark!
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark!
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt!
# Run away,…
# ```
#
#
# ## Goals
#
# 0. Use of string methods: **format()**, **str()**
# 1. Use of **for loop**
# 2. Use of the function **range()**
# 3. print()
# 4. Use of functions
# 5. Open files
# 6. Refactoring
#
# ## Hints
#
# * '\n' is the character for new line. It must end every string in the third step.
#
#
# ## Solution

# %%
# Variable

babyshark = '''Baby shark, doo doo doo doo doo doo
Baby shark, doo doo doo doo doo doo
Baby shark, doo doo doo doo doo doo
Baby shark!
Mommy shark, doo doo doo doo doo doo
Mommy shark, doo doo doo doo doo doo
Mommy shark, doo doo doo doo doo doo
Mommy shark!
Daddy shark, doo doo doo doo doo doo
Daddy shark, doo doo doo doo doo doo
Daddy shark, doo doo doo doo doo doo
Daddy shark!
Grandma shark, doo doo doo doo doo doo
Grandma shark, doo doo doo doo doo doo
Grandma shark, doo doo doo doo doo doo
Grandma shark!
Grandpa shark, doo doo doo doo doo doo
Grandpa shark, doo doo doo doo doo doo
Grandpa shark, doo doo doo doo doo doo
Grandpa shark!
Let's go hunt, doo doo doo doo doo doo
Let's go hunt, doo doo doo doo doo doo
Let's go hunt, doo doo doo doo doo doo
Let's go hunt!
Run away,…'''

# %% [markdown]
# ### Step 1: First Paragraph
# Create a code to print the first paragraph and asign it to a variable.

# %%
# your code here
def firstParagraph(song):
    firstParagraph = ""
    for i in song:
        firstParagraph += i
        if i == "!":
            break
    return firstParagraph

print(firstParagraph(babyshark))
# Out:
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!

# %% [markdown]
# **Expected output**:
#
# ```
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# ```

# %% [markdown]
# ### Step 2: Full song
#
# Create a code that prints the complete lyrics.

# %%
# your code here

print(babyshark)
# Out:
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark!
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark!
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark!
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark!
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt!
# Run away,…

# %% [markdown]
# **Expected output**:
#
# ```
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark!
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark!
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark!
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark!
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt!
# Run away,…
# ```
#
# ### Step 3: Check output
# Now i want you must create a string variable called **result** to store all the characters and check if it is equal to the lyrics. Remenber de hint section.

# %%
# your code here
result = ""

prefixes = ["Baby shark", "Mommy shark", "Daddy shark", "Grandma shark", "Grandpa shark", "Let's go hunt"]
sufix = ", doo doo doo doo doo doo\n"
ending_paragraph = "!\n"
final = "Run away,…"

for prefix in prefixes:
    paragraph = ""
    for character in prefix:
        paragraph += character
    paragraph += sufix
    paragraph *= 3 
    paragraph += prefix + ending_paragraph
    result += paragraph

result += final
        
print(result)
# Out:
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark!
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark!
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark!
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark!
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt!
# Run away,…

# %%
# Check

print(result == babyshark)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```
#
# ### Step 4: Function
#  Create a functions called babyshark() that generates the wanted output.

# %%
def baby_shark_lyrics():     
    result = ""
    prefixes = ["Baby shark", "Mommy shark", "Daddy shark", "Grandma shark", "Grandpa shark", "Let's go hunt"]
    for prefix in prefixes:
        p = ""
        for c in prefix:
            p += c
        p += ", doo doo doo doo doo doo\n"
        p *= 3 
        p += prefix + "!\n"
        result += p
    result += "Run away,…"
    return result

# %%
# Check

print(baby_shark_lyrics() == babyshark)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %% [markdown]
# ### Step 5: Files
# Baby shark lyrics can be read in the songs folder. Try to store the content of that file in a variable called **text** and check if it is equal to the babyshark variable and the output of your baby_shark_lyrics function.
#
# https://www.pythonforbeginners.com/files/reading-and-writing-files-in-python

# %%
baby_shark_txt = open("/Users/ana/prework-datamad-no-solutions/lyrics/songs/baby-shark.txt", "r")    
text = baby_shark_txt.read()

# %%
print(text == babyshark)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %%
print(baby_shark_lyrics() == text)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %% [markdown]
# ### Step 6: Refactor
# Now I want you to refactor your **baby_shark_lyrics** function in order to be less than 400 characters. If your code is larger than 400 characters, you should change baby_shark_lyrics function in order to shorten it.

# %%
import inspect

code = inspect.getsource(baby_shark_lyrics)

# check

print('Your baby_shark_lyrics functions has {} characters'.format(len(code)))
print(len(code) < 400)
# Out:
# Your baby_shark_lyrics functions has 396 characters
# True

# %% [markdown]
# **Expected output**:
#
# ```
# Your baby_shark_lyrics functions has 367 characters
# True
# ```

# %% [markdown]
# ## Bonus
#
# http://www.99-bottles-of-beer.net/
#
# Now let`s try with another lyric, you can find it in songs folder.
#
# ### Step 1. Create bottles_lyrics function

# %%
def bottles_lyrics():
    b = "bottle"
    sufix = " of beer on the wall"
    sufix_2 = " of beer.\n"
    common = "Take one down and pass it around, "
    result = ""
    for n_bottles in range(99, 0, -1):
        _bottles = n_bottles - 1
        if n_bottles > 1:
            result += str(n_bottles) + " " + b + "s" + sufix + ", " + str(n_bottles) + " " + b + "s" + sufix_2
        else:
            result += str(n_bottles) + " " + b + sufix + ", " + str(n_bottles) + " " + b + sufix_2 
        if _bottles >= 1:
            if _bottles == 1:
                result += common + str(_bottles) + " " + b + sufix + ".\n"
            else:
                result += common + str(_bottles) + " " + b + "s" + sufix + ".\n"
        else:
            result += common + "no more bottles of beer on the wall.\n" 
        result += "\n"
    result += "No more bottles of beer on the wall, no more bottles of beer.\nGo to the store and buy some more, 99 bottles of beer on the wall."
    return result

# %% [markdown]
# ### Step 2. Open file

# %%
bottles_of_beer_txt = open("/Users/ana/prework-datamad-no-solutions/lyrics/songs/99-bottes-of-beer.txt", "r")    
text = bottles_of_beer_txt.read()

# %%
# Check

print(bottles_lyrics() == text)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %% [markdown]
# ### Step 3: Check code
# Now I want you to refactor your **bottles_lyrics** function in order to be less than 1000 characters.

# %%
import inspect

code = inspect.getsource(bottles_lyrics)

# %%
# check

print('Your bottles_lyrics functions has {} characters'.format(len(code)))
print(len(code) < 1000)
# Out:
# Your bottles_lyrics functions has 995 characters
# True

# %% [markdown]
# **Expected output**:
#
# ```
# Your bottles_lyrics functions has 837 characters
# True
# ```

# %% [markdown]
# If you want a real challenge, follow the link below. Sign in and start coding!
#
# https://www.codewars.com/kata/baby-shark-lyrics-generator/train/python
