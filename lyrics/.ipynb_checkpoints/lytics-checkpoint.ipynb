# %% [markdown]
# # Lyrics
# ## Intro
# This exercise is simple. You are going to create a code that writes the lyrics of a famous song. **The shorter your code is, the better**. Although it may seem a bit silly, it is important that you learn to automate repetitive tasks or that there are few changes between them.
#
# <img src="./images/babyshark.jpeg" width="400">
#
# ## Song
#
# ```
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark!
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark!
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark!
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark!
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt!
# Run away,…
# ```
#
#
# ## Goals
#
# 0. Use of string methods: **format()**, **str()**
# 1. Use of **for loop**
# 2. Use of the function **range()**
# 3. print()
# 4. Use of functions
# 5. Open files
# 6. Refactoring
#
# ## Hints
#
# * '\n' is the character for new line. It must end every string in the third step.
#
#
# ## Solution

# %%
# Variable

babyshark = '''Baby shark, doo doo doo doo doo doo
Baby shark, doo doo doo doo doo doo
Baby shark, doo doo doo doo doo doo
Baby shark!
Mommy shark, doo doo doo doo doo doo
Mommy shark, doo doo doo doo doo doo
Mommy shark, doo doo doo doo doo doo
Mommy shark!
Daddy shark, doo doo doo doo doo doo
Daddy shark, doo doo doo doo doo doo
Daddy shark, doo doo doo doo doo doo
Daddy shark!
Grandma shark, doo doo doo doo doo doo
Grandma shark, doo doo doo doo doo doo
Grandma shark, doo doo doo doo doo doo
Grandma shark!
Grandpa shark, doo doo doo doo doo doo
Grandpa shark, doo doo doo doo doo doo
Grandpa shark, doo doo doo doo doo doo
Grandpa shark!
Let's go hunt, doo doo doo doo doo doo
Let's go hunt, doo doo doo doo doo doo
Let's go hunt, doo doo doo doo doo doo
Let's go hunt!
Run away,…'''

# %% [markdown]
# ### Step 1: First Paragraph
# Create a code to print the first paragraph and asign it to a variable.

# %%
# your code here

lines = babyshark.split("\n")

first_paragraph = ""

for i in range(4):
  first_paragraph += lines[i] + "\n"

print(first_paragraph)
# Out:
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!

# %% [markdown]
# **Expected output**:
#
# ```
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# ```

# %% [markdown]
# ### Step 2: Full song
#
# Create a code that prints the complete lyrics.

# %%
# your code here

for i in lines:
  print(i)
# Out:
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark!
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark!
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark!
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark!
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt!
# Run away,…

# %% [markdown]
# **Expected output**:
#
# ```
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark!
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark!
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark!
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark!
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt!
# Run away,…
# ```
#
# ### Step 3: Check output
# Now i want you must create a string variable called **result** to store all the characters and check if it is equal to the lyrics. Remenber de hint section.

# %%
# your code here

result = ""
for i in babyshark:
  result += i

# %%
# Check

print(result == babyshark)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```
#
# ### Step 4: Function
#  Create a functions called babyshark() that generates the wanted output.

# %%
def baby_shark_lyrics():
    # your code here
  song = ""
  starts = ["Baby shark", "Mommy shark", "Daddy shark", "Grandma shark", "Grandpa shark", "Let's go hunt"]
  for i in starts:
    for x in range(4):
      if x <=2:
        song += i + "," + " doo"*6 + "\n"
      else:
        song += i + "!" + "\n"
  song += "Run away,…"
  return song

# %%
# Check

print(baby_shark_lyrics() == babyshark)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %% [markdown]
# ### Step 5: Files
# Baby shark lyrics can be read in the songs folder. Try to store the content of that file in a variable called **text** and check if it is equal to the babyshark variable and the output of your baby_shark_lyrics function.
#
# https://www.pythonforbeginners.com/files/reading-and-writing-files-in-python

# %%
# your code here

from pathlib import Path

data_folder = Path("songs/")
file_to_open = data_folder / "baby-shark.txt"

file = open(file_to_open)
text = file.read()

# %%
# check

print(text == babyshark)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %%
# Check

print(baby_shark_lyrics() == text)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %% [markdown]
# ### Step 6: Refactor
# Now I want you to refactor your **baby_shark_lyrics** function in order to be less than 400 characters. If your code is larger than 400 characters, you should change baby_shark_lyrics function in order to shorten it.

# %%
import inspect

code = inspect.getsource(baby_shark_lyrics)

# check

print('Your baby_shark_lyrics functions has {} characters'.format(len(code)))
print(len(code) < 400)
# Out:
# Your baby_shark_lyrics functions has 345 characters
# True

# %% [markdown]
# **Expected output**:
#
# ```
# Your baby_shark_lyrics functions has 367 characters
# True
# ```

# %% [markdown]
# ## Bonus
#
# http://www.99-bottles-of-beer.net/
#
# Now let`s try with another lyric, you can find it in songs folder.
#
# ### Step 1. Create bottles_lyrics function

# %%
def bottles_lyrics():
    # your code here. 
  song = ""
  for i in range(99, 0, -1):
    if i > 1:
      song += str(i) + " bottles of beer on the wall, " + str(i) + " bottles of beer." + "\n"
      if i > 2:
        suffix = str(i - 1) + " bottles of beer on the wall."
      else:
        suffix = "1 bottle of beer on the wall."
    elif i == 1:
      song += "1 bottle of beer on the wall, 1 bottle of beer." + "\n"
      suffix = "no more bottles of beer on the wall."
    song += "Take one down and pass it around, " + suffix + "\n"*2
  song += "No more bottles of beer on the wall, no more bottles of beer." + "\n" + "Go to the store and buy some more, 99 bottles of beer on the wall."
  return song

# %% [markdown]
# ### Step 2. Open file

# %%
# your code here. 

from pathlib import Path

data_folder = Path("songs/")
file_to_open = data_folder / "99-bottes-of-beer.txt"

file = open(file_to_open)
text = file.read()

# %%
# Check

print(bottles_lyrics() == text)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %% [markdown]
# ### Step 3: Check code
# Now I want you to refactor your **bottles_lyrics** function in order to be less than 1000 characters.

# %%
import inspect

code = inspect.getsource(bottles_lyrics)

# %%
# check

print('Your bottles_lyrics functions has {} characters'.format(len(code)))
print(len(code) < 1000)
# Out:
# Your bottles_lyrics functions has 708 characters
# True

# %% [markdown]
# **Expected output**:
#
# ```
# Your bottles_lyrics functions has 837 characters
# True
# ```

# %% [markdown]
# If you want a real challenge, follow the link below. Sign in and start coding!
#
# https://www.codewars.com/kata/baby-shark-lyrics-generator/train/python
