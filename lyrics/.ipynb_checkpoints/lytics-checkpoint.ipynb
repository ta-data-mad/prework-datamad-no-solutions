# %% [markdown]
# # Lyrics
# ## Intro
# This exercise is simple. You are going to create a code that writes the lyrics of a famous song. **The shorter your code is, the better**. Although it may seem a bit silly, it is important that you learn to automate repetitive tasks or that there are few changes between them.
#
# <img src="./images/babyshark.jpeg" width="400">
#
# ## Song
#
# ```
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark!
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark!
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark!
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark!
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt!
# Run away,…
# ```
#
#
# ## Goals
#
# 0. Use of string methods: **format()**, **str()**
# 1. Use of **for loop**
# 2. Use of the function **range()**
# 3. print()
# 4. Use of functions
# 5. Open files
# 6. Refactoring
#
# ## Hints
#
# * '\n' is the character for new line. It must end every string in the third step.
#
#
# ## Solution

# %%
# Variable

babyshark = '''Baby shark, doo doo doo doo doo doo
Baby shark, doo doo doo doo doo doo
Baby shark, doo doo doo doo doo doo
Baby shark!
Mommy shark, doo doo doo doo doo doo
Mommy shark, doo doo doo doo doo doo
Mommy shark, doo doo doo doo doo doo
Mommy shark!
Daddy shark, doo doo doo doo doo doo
Daddy shark, doo doo doo doo doo doo
Daddy shark, doo doo doo doo doo doo
Daddy shark!
Grandma shark, doo doo doo doo doo doo
Grandma shark, doo doo doo doo doo doo
Grandma shark, doo doo doo doo doo doo
Grandma shark!
Grandpa shark, doo doo doo doo doo doo
Grandpa shark, doo doo doo doo doo doo
Grandpa shark, doo doo doo doo doo doo
Grandpa shark!
Let's go hunt, doo doo doo doo doo doo
Let's go hunt, doo doo doo doo doo doo
Let's go hunt, doo doo doo doo doo doo
Let's go hunt!
Run away,…'''

# %% [markdown]
# ### Step 1: First Paragraph
# Create a code to print the first paragraph and asign it to a variable.

# %%
# your code here
do = "doo doo doo doo doo doo"
baby = "Baby shark,"
print(baby, do)
print(baby, do)
print(baby, do)
print(baby, "!")
# Out:
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, !

# %% [markdown]
# **Expected output**:
#
# ```
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# ```

# %% [markdown]
# ### Step 2: Full song
#
# Create a code that prints the complete lyrics.

# %%
# your code here

mommy = "Mommy shark,"
daddy = "Daddy shark,"
grandpa = "Grandpa shark,"
end = "Let´s go hunt,"

print(baby, do)
print(baby, do)
print(baby, do)
print(baby, "!")

print(mommy, do)
print(mommy, do)
print(mommy, do)
print(mommy, "!")

print(daddy, do)
print(daddy, do)
print(daddy, do)
print(daddy, "!")

print(grandpa, do)
print(grandpa, do)
print(grandpa, do)
print(grandpa, "!")

print(end, do)
print(end, do)
print(end, do)
print(end, "!")
print("Run away,...")
# Out:
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, !
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, !
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, !
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, !
# Let´s go hunt, doo doo doo doo doo doo
# Let´s go hunt, doo doo doo doo doo doo
# Let´s go hunt, doo doo doo doo doo doo
# Let´s go hunt, !
# Run away,...

# %% [markdown]
# **Expected output**:
#
# ```
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark, doo doo doo doo doo doo
# Baby shark!
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark, doo doo doo doo doo doo
# Mommy shark!
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark, doo doo doo doo doo doo
# Daddy shark!
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark, doo doo doo doo doo doo
# Grandma shark!
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark, doo doo doo doo doo doo
# Grandpa shark!
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt, doo doo doo doo doo doo
# Let's go hunt!
# Run away,…
# ```
#
# ### Step 3: Check output
# Now i want you must create a string variable called **result** to store all the characters and check if it is equal to the lyrics. Remenber de hint section.

# %%
# your code here

Baby shark, doo doo doo doo doo doo
Baby shark, doo doo doo doo doo doo
Baby shark!
Mommy shark, doo doo doo doo doo doo
Mommy shark, doo doo doo doo doo doo
Mommy shark, doo doo doo doo doo doo
Mommy shark!
Daddy shark, doo doo doo doo doo doo
Daddy shark, doo doo doo doo doo doo
Daddy shark, doo doo doo doo doo doo
Daddy shark!
Grandma shark, doo doo doo doo doo doo
Grandma shark, doo doo doo doo doo doo
Grandma shark, doo doo doo doo doo doo
Grandma shark!
Grandpa shark, doo doo doo doo doo doo
Grandpa shark, doo doo doo doo doo doo
Grandpa shark, doo doo doo doo doo doo
Grandpa shark!
Let's go hunt, doo doo doo doo doo doo
Let's go hunt, doo doo doo doo doo doo
Let's go hunt, doo doo doo doo doo doo
Let's go hunt!
Run away,…''')
# Out:
#   File "<ipython-input-61-41d8bf4d1110>", line 2
#     lyrics = "Baby shark, doo doo doo doo doo doo n\Baby shark, doo doo doo doo doo doo n\Baby shark, doo doo doo doo doo doo n\"
#                                                                                                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
# Check
print(result == babyshark)
# Out:
# True

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```
#
# ### Step 4: Function
#  Create a functions called babyshark() that generates the wanted output.

# %%
def baby_shark_lyrics():
    # your code here
  for i in babyshark:
    print(babyshark)

# %%
# Check

print(baby_shark_lyrics() == babyshark)
# Out:
# B
# a
# b
# y
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# B
# a
# b
# y
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# B
# a
# b
# y
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# B
# a
# b
# y
#
# s
# h
# a
# r
# k
# !
#
#
# M
# o
# m
# m
# y
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# M
# o
# m
# m
# y
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# M
# o
# m
# m
# y
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# M
# o
# m
# m
# y
#
# s
# h
# a
# r
# k
# !
#
#
# D
# a
# d
# d
# y
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# D
# a
# d
# d
# y
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# D
# a
# d
# d
# y
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# D
# a
# d
# d
# y
#
# s
# h
# a
# r
# k
# !
#
#
# G
# r
# a
# n
# d
# m
# a
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# G
# r
# a
# n
# d
# m
# a
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# G
# r
# a
# n
# d
# m
# a
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# G
# r
# a
# n
# d
# m
# a
#
# s
# h
# a
# r
# k
# !
#
#
# G
# r
# a
# n
# d
# p
# a
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# G
# r
# a
# n
# d
# p
# a
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# G
# r
# a
# n
# d
# p
# a
#
# s
# h
# a
# r
# k
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# G
# r
# a
# n
# d
# p
# a
#
# s
# h
# a
# r
# k
# !
#
#
# L
# e
# t
# '
# s
#
# g
# o
#
# h
# u
# n
# t
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# L
# e
# t
# '
# s
#
# g
# o
#
# h
# u
# n
# t
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# L
# e
# t
# '
# s
#
# g
# o
#
# h
# u
# n
# t
# ,
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
# d
# o
# o
#
#
# L
# e
# t
# '
# s
#
# g
# o
#
# h
# u
# n
# t
# !
#
#
# R
# u
# n
#
# a
# w
# a
# y
# ,
# …
# False

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %% [markdown]
# ### Step 5: Files
# Baby shark lyrics can be read in the songs folder. Try to store the content of that file in a variable called **text** and check if it is equal to the babyshark variable and the output of your baby_shark_lyrics function.
#
# https://www.pythonforbeginners.com/files/reading-and-writing-files-in-python

# %%
# your code here
text = open("prework-datamad-no-solutions/lyrics/songs/baby-shark.txt", "r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-82-702e80e6d064> in <module>
#       1 # your code here
# ----> 2 text = open("prework-datamad-no-solutions/lyrics/songs/baby-shark.txt", "r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prework-datamad-no-solutions/lyrics/songs/baby-shark.txt'

# %%
# check

print(text == babyshark)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-7db9c48d3821> in <module>
#       1 # check
#       2
# ----> 3 print(text == babyshark)
#
# NameError: name 'text' is not defined

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %%
# Check

print(baby_shark_lyrics() == text)

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %% [markdown]
# ### Step 6: Refactor
# Now I want you to refactor your **baby_shark_lyrics** function in order to be less than 400 characters. If your code is larger than 400 characters, you should change baby_shark_lyrics function in order to shorten it.

# %%
import inspect

code = inspect.getsource(baby_shark_lyrics)

# check

print('Your baby_shark_lyrics functions has {} characters'.format(len(code)))
print(len(code) < 400)

# %% [markdown]
# **Expected output**:
#
# ```
# Your baby_shark_lyrics functions has 367 characters
# True
# ```

# %% [markdown]
# ## Bonus
#
# http://www.99-bottles-of-beer.net/
#
# Now let`s try with another lyric, you can find it in songs folder.
#
# ### Step 1. Create bottles_lyrics function

# %%
def bottles_lyrics():
    # your code here.

# %% [markdown]
# ### Step 2. Open file

# %%
# your code here.

# %%
# Check

print(bottles_lyrics() == text)

# %% [markdown]
# **Expected output**:
#
# ```
# True
# ```

# %% [markdown]
# ### Step 3: Check code
# Now I want you to refactor your **bottles_lyrics** function in order to be less than 1000 characters.

# %%
import inspect

code = inspect.getsource(bottles_lyrics)

# %%
# check

print('Your bottles_lyrics functions has {} characters'.format(len(code)))
print(len(code) < 1000)

# %% [markdown]
# **Expected output**:
#
# ```
# Your bottles_lyrics functions has 837 characters
# True
# ```

# %% [markdown]
# If you want a real challenge, follow the link below. Sign in and start coding!
#
# https://www.codewars.com/kata/baby-shark-lyrics-generator/train/python
