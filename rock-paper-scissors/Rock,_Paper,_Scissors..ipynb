# %%
import random




game=["Rock","Paper","Scissors"]




plays=5



to_win=3


user_option=[]

user_score=0
machine_score=0


        


while plays > 0 :
    
    machine =random.choice(game)
    user_option=(input("What´s your choice? Rock, Paper or Scissors: "))


    print( "Computer chose: ", machine)
    
    if user_option == machine:
        print("Tie!")
    elif user_option == machine:
        print("Wrong answer")
    
    elif user_option == "Paper" and machine == "Rock":
        user_score +=2
        print("You won!", user_score, "to",machine_score)
        plays -=1
        
        
    elif user_option == "Rock" and machine == "Scissors":
        user_score +=2
        print("You won!", user_score, "to",machine_score)
        plays -=1
        
        
    elif user_option == "Scissors" and machine == "Paper":
        user_score +=2
        print("You won!", user_score, "to",machine_score)
        plays -=1
        
        
    else:
        machine_score +=1
        print("You lose", user_score, "to", machine_score)
        plays-=1
        
        


        print("Last", plays,"plays")
print(user_score)
print(machine_score)
   



       
if user_score > machine_score:
    print("The winner is... the user!")
else:
    print("The winner is... the machine!")
# Out:
# What´s your choice? Rock, Paper or Scissors: Paper
# Computer chose:  Scissors
# You lose 0 to 1
# Last 4 plays
# What´s your choice? Rock, Paper or Scissors: Rock
# Computer chose:  Scissors
# You won! 2 to 1
# What´s your choice? Rock, Paper or Scissors: Paper
# Computer chose:  Paper
# Tie!
# What´s your choice? Rock, Paper or Scissors: Paper
# Computer chose:  Scissors
# You lose 2 to 2
# Last 2 plays
# What´s your choice? Rock, Paper or Scissors: Rock
# Computer chose:  Scissors
# You won! 4 to 2
# What´s your choice? Rock, Paper or Scissors: Scissors
# Computer chose:  Scissors
# Tie!
# What´s your choice? Rock, Paper or Scissors: Scissors
# Computer chose:  Scissors
# Tie!
# What´s your choice? Rock, Paper or Scissors: Paper
# Computer chose:  Paper
# Tie!
# What´s your choice? Rock, Paper or Scissors: Rock
# Computer chose:  Scissors
# You won! 6 to 2
# 6
# 2
# The winner is... the user!
